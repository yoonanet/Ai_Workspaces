# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import LSTM, Dense

from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from sklearn.model_selection import cross_val_score

# %%
# 데이터 불러오기
df = pd.read_csv('project2_data/df.csv')
df1 = pd.read_csv('project2_data/aptpre.csv')

# %%
df.head() #16-18까지의 데이터
# Out:
#      동   단지명    전용면적    계약년월  층  건축년도   금리  부동산소비심리    보증금
# 0  165  2059   79.97  201601  4  1987  1.5    117.6  44000
# 1  165  2059   79.97  201601  3  1987  1.5    117.6  42000
# 2  165   453  133.46  201601  8  1984  1.5    117.6  80000
# 3  165   453  104.43  201601  6  1984  1.5    117.6  52000
# 4  165   453  104.43  201601  3  1984  1.5    117.6  55000

# %%
df1.head() #19-23까지의 데이터
# Out:
#     동   단지명    전용면적    계약년월   층    건축년도    금리  부동산소비심리    보증금
# 0  83  2615   79.97  201901   7  1987.0  1.75     91.8  41000
# 1  83  2615   79.97  201901   6  1987.0  1.75     91.8  38000
# 2  83   590  161.00  201901  10  1984.0  1.75     91.8  90000
# 3  83   590  104.43  201901  16  1984.0  1.75     91.8  55000
# 4  83  2274   83.17  201901   7  1983.0  1.75     91.8  51000

# %%
df.describe()
# Out:
#                    동            단지명           전용면적           계약년월  \
# count  320979.000000  320979.000000  320979.000000  320979.000000
# mean      153.538200    2682.592419      76.076619  201711.545668
# std        88.406449    1679.933238      26.141417      82.104811
# min         0.000000       0.000000      10.110000  201601.000000
# 25%        70.000000    1352.000000      59.680000  201610.000000
# 50%       159.000000    2269.000000      80.920000  201707.000000
# 75%       235.000000    3925.000000      84.960000  201804.000000
# max       331.000000    6632.000000     317.360000  201812.000000
#
#                    층           건축년도             금리        부동산소비심리  \
# count  320979.000000  320979.000000  320979.000000  320979.000000
# mean       10.691213    1998.759458       1.388802     118.405118
# std         5.780531      10.723342       0.140256       8.987102
# min         0.000000    1961.000000       1.250000      93.900000
# 25%         6.000000    1990.000000       1.250000     113.100000
# 50%        10.000000    1999.000000       1.500000     119.200000
# 75%        14.000000    2007.000000       1.500000     126.300000
# max        68.000000    2018.000000       1.750000     134.100000
#
#                  보증금
# count  320979.000000
# mean    39010.146888
# std     18613.787295
# min       500.000000
# 25%     26000.000000
# 50%     37000.000000
# 75%     50000.000000
# max    100000.000000

# %%
# 정규화하기
# MinMaxScaler 클래스 생성
scaler = MinMaxScaler()

# MinMaxScaler 클래스의 fit_transform() 메서드 사용 데이터 정규화
normalized_data = scaler.fit_transform(df)
normalized_data1 = scaler.fit_transform(df1)

# 정규화된 데이터, 데이터 프레임으로 다시 변환
normalized_df = pd.DataFrame(normalized_data, columns=df.columns)
normalized_df1 = pd.DataFrame(normalized_data1, columns=df1.columns)

# %%
normalized_df.head()
# Out:
#           동       단지명      전용면적  계약년월         층      건축년도   금리   부동산소비심리  \
# 0  0.498489  0.310464  0.227372   0.0  0.058824  0.456140  0.5  0.589552
# 1  0.498489  0.310464  0.227372   0.0  0.044118  0.456140  0.5  0.589552
# 2  0.498489  0.068305  0.401465   0.0  0.117647  0.403509  0.5  0.589552
# 3  0.498489  0.068305  0.306981   0.0  0.088235  0.403509  0.5  0.589552
# 4  0.498489  0.068305  0.306981   0.0  0.044118  0.403509  0.5  0.589552
#
#         보증금
# 0  0.437186
# 1  0.417085
# 2  0.798995
# 3  0.517588
# 4  0.547739

# %%
normalized_df1 = normalized_df1.dropna(axis=0)

normalized_df1.head()
# Out:
#           동       단지명      전용면적  계약년월         층      건축년도        금리   부동산소비심리  \
# 0  0.248503  0.360789  0.226840   0.0  0.112903  0.419355  0.416667  0.658537
# 1  0.248503  0.360789  0.226840   0.0  0.096774  0.419355  0.416667  0.658537
# 2  0.248503  0.081402  0.490748   0.0  0.161290  0.370968  0.416667  0.658537
# 3  0.248503  0.081402  0.306504   0.0  0.258065  0.370968  0.416667  0.658537
# 4  0.248503  0.313742  0.237262   0.0  0.112903  0.354839  0.416667  0.658537
#
#         보증금
# 0  0.407035
# 1  0.376884
# 2  0.899497
# 3  0.547739
# 4  0.507538

# %%
nan_count = df.isnull().sum().sum()
print("NaN 값이 있는 행 개수:", nan_count)
# Out:
# NaN 값이 있는 행 개수: 0

# %%
ndf = normalized_df.copy()
ndf1 = normalized_df1.copy() #19-23데이터_정규화 처리

# %%
# 데이터 나누기
X = ndf.iloc[:, :-1]
y = ndf.iloc[:,[-1]]

X1 = ndf1.iloc[:, :-1]
y1 = ndf1.iloc[:,[-1]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
pd.DataFrame(X_test).to_csv('project2_data/X_test.csv', index=False)
pd.DataFrame(y_test).to_csv('project2_data/y_test.csv', index=False)

# %%
X_test = pd.read_csv('project2_data/X_test.csv')
y_test = pd.read_csv('project2_data/y_test.csv')

# %%
y_test.head()
# Out:
#         보증금
# 0  0.195980
# 1  0.316583
# 2  0.256281
# 3  0.236181
# 4  0.376884

# %%
y1.head()
# Out:
#         보증금
# 0  0.407035
# 1  0.376884
# 2  0.899497
# 3  0.547739
# 4  0.507538

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (256783, 8)
# (256783, 1)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (64196, 8)
# (64196, 1)

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(ndf.shape[1] - 1, 1)))
model.add(Dense(1))
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='mse')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, y, epochs=40, batch_size=32, verbose=1)
# Out:
# Epoch 1/40
# 10031/10031 [==============================] - 44s 4ms/step - loss: 0.0096
# Epoch 2/40
# 10031/10031 [==============================] - 40s 4ms/step - loss: 0.0058
# Epoch 3/40
# 10031/10031 [==============================] - 41s 4ms/step - loss: 0.0056
# Epoch 4/40
# 10031/10031 [==============================] - 41s 4ms/step - loss: 0.0054
# Epoch 5/40
# 10031/10031 [==============================] - 42s 4ms/step - loss: 0.0053
# Epoch 6/40
#  2866/10031 [=======>......................] - ETA: 29s - loss: 0.0052

# %%
#pred = model.predict(X_test)
pred = model.predict(X1) #19-23 예측값
print(y1.shape, pred.shape)
# Out:
# 18429/18429 [==============================] - 41s 2ms/step
# (589726, 1) (589726, 1)

# %%
# 실제값과 예측값을 계약년월별 평균값으로 계산
predictions = np.array(pred)
actual_values = np.array(y1)

# %%
contract_year_predictions = np.array([predictions[i:i + 12].mean() for i in range(0, len(predictions), 12)])
contract_year_actual_values = np.array([actual_values[i:i + 12].mean() for i in range(0, len(actual_values), 12)])

# %%
plt.plot(contract_year_predictions, label="Predictions", linestyle='solid')
plt.plot(contract_year_actual_values, label="Actual Values")
plt.xlabel("Contract Year")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
# RMSE를 계산(낮을 수록 정확함)
rmse = mean_squared_error(y1, predictions)
print('rmse :',rmse)

# R^2을 계산(R^2가 1에 가까울수록 모델이 데이터를 잘 설명)
r2 = r2_score(y1, predictions)
print('r2 :',r2)

# MAE를 계산(MAE가 낮을수록 예측값과 실제값이 가까워짐)
mae = mean_absolute_error(y1, predictions)
print('mae :',mae)

#rmse : 0.0034132945240048142
#r2 : 0.9021169367226671
#mae : 0.03591461482859955

#rmse : 0.0033472387605986563
#r2 : 0.90475347178065
#mae : 0.035972331743353736
# Out:
# rmse : 0.020196391945882273
# r2 : 0.5399109302704829
# mae : 0.11369135635227774

# %%
# 계약년월을 기준으로 그룹핑을 합니다.
df_mean = df.groupby('계약년월')['보증금'].mean()

# %%
df_mean
# Out:
# 계약년월
# 201601    36890.038096
# 201602    35449.676327
# 201603    34559.563102
# 201604    34928.067398
# 201605    36347.804235
# 201606    37026.997471
# 201607    36044.919882
# 201608    35499.391133
# 201609    37310.437418
# 201610    38790.171271
# 201611    39276.176147
# 201612    40789.602979
# 201701    39552.181829
# 201702    38442.548583
# 201703    37001.654835
# 201704    38238.596794
# 201705    38444.156503
# 201706    38308.968900
# 201707    38631.311260
# 201708    37868.142969
# 201709    39020.065737
# 201710    39331.802162
# 201711    41292.052638
# 201712    41946.613463
# 201801    41205.055759
# 201802    40172.497791
# 201803    39456.268185
# 201804    39304.877134
# 201805    39401.404901
# 201806    40542.906301
# 201807    40033.113482
# 201808    40175.420574
# 201809    40848.639097
# 201810    41695.576178
# 201811    42500.864625
# 201812    43545.275127
# Name: 보증금, dtype: float64

# %%
X1['예측값'] = pred

# %%
X1.head()
# Out:
#           동       단지명      전용면적  계약년월         층      건축년도        금리   부동산소비심리  \
# 0  0.248503  0.360789  0.226840   0.0  0.112903  0.419355  0.416667  0.658537
# 1  0.248503  0.360789  0.226840   0.0  0.096774  0.419355  0.416667  0.658537
# 2  0.248503  0.081402  0.490748   0.0  0.161290  0.370968  0.416667  0.658537
# 3  0.248503  0.081402  0.306504   0.0  0.258065  0.370968  0.416667  0.658537
# 4  0.248503  0.313742  0.237262   0.0  0.112903  0.354839  0.416667  0.658537
#
#         예측값
# 0  0.502412
# 1  0.500117
# 2  0.753876
# 3  0.558098
# 4  0.525156

# %%
pd.DataFrame(X1).to_csv('project2_data/X_result.csv', index=False)

# %%
result = pd.read_csv('project2_data/X_result.csv')

# %%
result.head()
# Out:
#           동       단지명      전용면적  계약년월         층      건축년도        금리   부동산소비심리  \
# 0  0.248503  0.360789  0.226840   0.0  0.112903  0.419355  0.416667  0.658537
# 1  0.248503  0.360789  0.226840   0.0  0.096774  0.419355  0.416667  0.658537
# 2  0.248503  0.081402  0.490748   0.0  0.161290  0.370968  0.416667  0.658537
# 3  0.248503  0.081402  0.306504   0.0  0.258065  0.370968  0.416667  0.658537
# 4  0.248503  0.313742  0.237262   0.0  0.112903  0.354839  0.416667  0.658537
#
#         예측값
# 0  0.502412
# 1  0.500117
# 2  0.753876
# 3  0.558098
# 4  0.525157

# %%
result = pd.concat([result, y1], axis=1)

# %%
result.head()
# Out:
#           동       단지명      전용면적  계약년월         층      건축년도        금리   부동산소비심리  \
# 0  0.248503  0.360789  0.226840   0.0  0.112903  0.419355  0.416667  0.658537
# 1  0.248503  0.360789  0.226840   0.0  0.096774  0.419355  0.416667  0.658537
# 2  0.248503  0.081402  0.490748   0.0  0.161290  0.370968  0.416667  0.658537
# 3  0.248503  0.081402  0.306504   0.0  0.258065  0.370968  0.416667  0.658537
# 4  0.248503  0.313742  0.237262   0.0  0.112903  0.354839  0.416667  0.658537
#
#         예측값       보증금
# 0  0.490904  0.407035
# 1  0.488667  0.376884
# 2  0.755162  0.899497
# 3  0.558082  0.547739
# 4  0.521126  0.507538

# %%
result = result[['동', '단지명', '전용면적', '계약년월', '층', '건축년도', '금리', '부동산소비심리', '예측값', '보증금']]

# %%
result.head()
# Out:
#           동       단지명      전용면적  계약년월         층      건축년도        금리   부동산소비심리  \
# 0  0.248503  0.360789  0.226840   0.0  0.112903  0.419355  0.416667  0.658537
# 1  0.248503  0.360789  0.226840   0.0  0.096774  0.419355  0.416667  0.658537
# 2  0.248503  0.081402  0.490748   0.0  0.161290  0.370968  0.416667  0.658537
# 3  0.248503  0.081402  0.306504   0.0  0.258065  0.370968  0.416667  0.658537
# 4  0.248503  0.313742  0.237262   0.0  0.112903  0.354839  0.416667  0.658537
#
#         예측값       보증금
# 0  0.490904  0.407035
# 1  0.488667  0.376884
# 2  0.755162  0.899497
# 3  0.558082  0.547739
# 4  0.521126  0.507538

# %%
result = result.groupby('계약년월').mean()
result = result[['보증금', '예측값']]

# %%
print(result)
# Out:
#                보증금       예측값
# 계약년월
# 0.000000  0.415984  0.502927
# 0.002469  0.407865  0.499430
# 0.004938  0.385000  0.482511
# 0.007407  0.391755  0.482536
# 0.009877  0.395543  0.477728
# 0.012346  0.390687  0.467249
# 0.014815  0.400583  0.472578
# 0.017284  0.389876  0.463972
# 0.019753  0.396109  0.466274
# 0.022222  0.410452  0.474780
# 0.024691  0.429113  0.492506
# 0.027160  0.429334  0.488457
# 0.246914  0.416391  0.479288
# 0.249383  0.409886  0.470279
# 0.251852  0.401737  0.458088
# 0.254321  0.400787  0.450986
# 0.256790  0.415904  0.459944
# 0.259259  0.438407  0.473450
# 0.261728  0.435510  0.463533
# 0.264198  0.424033  0.452092
# 0.266667  0.434940  0.442407
# 0.269136  0.452320  0.452729
# 0.271605  0.471678  0.464306
# 0.274074  0.482153  0.467046
# 0.493827  0.470985  0.464929
# 0.496296  0.461715  0.462809
# 0.498765  0.448564  0.450981
# 0.501235  0.453900  0.451583
# 0.503704  0.480604  0.464477
# 0.506173  0.463861  0.443732
# 0.508642  0.471595  0.446638
# 0.511111  0.443897  0.436050
# 0.513580  0.457808  0.441804
# 0.516049  0.475695  0.458458
# 0.518519  0.487584  0.467810
# 0.520988  0.488114  0.476443
# 0.740741  0.481845  0.480726
# 0.743210  0.464876  0.475347
# 0.745679  0.453482  0.460180
# 0.748148  0.466117  0.460451
# 0.750617  0.459534  0.458808
# 0.753086  0.475881  0.468542
# 0.755556  0.457143  0.465443
# 0.758025  0.451038  0.472645
# 0.760494  0.465295  0.471829
# 0.762963  0.473833  0.482522
# 0.765432  0.465922  0.485746
# 0.767901  0.478205  0.508742
# 0.987654  0.465059  0.517759
# 0.990123  0.449717  0.501553
# 0.992593  0.442854  0.501926
# 0.995062  0.447930  0.507417
# 0.997531  0.456587  0.505119
# 1.000000  0.445087  0.486343

# %%
plt.plot(result['보증금'], label='real')
plt.plot(result['예측값'], linestyle='--', label='predict')
plt.title('predict vs real')
plt.xlabel('period')
plt.ylabel('deposit')
plt.legend()
plt.show()

# %%
# 본래값 확인해보기
# 201901
print('실제값 : ',0.415984 * (100000.0-500.0)+500)
print('예측값 : ',0.502927 * (100000.0-500.0)+500)

#201902
print('실제값 : ',0.407865 * (100000.0-500.0)+500)
print('예측값 : ',0.499430 * (100000.0-500.0)+500)

# 201903
print('실제값 : ',0.385000 * (100000.0-500.0)+500)
print('예측값 : ',0.482511 * (100000.0-500.0)+500)
# Out:
# 실제값 :  41890.408
# 예측값 :  50541.2365
# 실제값 :  41082.5675
# 예측값 :  50193.284999999996
# 실제값 :  38807.5
# 예측값 :  48509.8445

# %%
result = result * (100000 - 500) + 500
print('역정규화된 데이터\n', result)
# Out:
# 역정규화된 데이터
#                     동           단지명          전용면적      계약년월             층  \
# 0       25226.047904  36398.523731  23070.543271     500.0  11733.870968
# 1       25226.047904  36398.523731  23070.543271     500.0  10129.032258
# 2       25226.047904   8599.475717  49329.416344     500.0  16548.387097
# 3       25226.047904   8599.475717  30997.138795     500.0  26177.419355
# 4       25226.047904  31717.301325  24107.546773     500.0  11733.870968
# ...              ...           ...           ...       ...           ...
# 589721  85104.790419  54972.406181  24697.342516  100000.0  16548.387097
# 589722  74082.335329  94961.851545   2968.878496  100000.0  24572.580645
# 589723  74082.335329  56729.580574  16521.218023  100000.0  21362.903226
# 589724  74082.335329  56729.580574  13478.260870  100000.0  13338.709677
# 589725  74082.335329  56729.580574  16521.218023  100000.0  39016.129032
#
#                 건축년도             금리       부동산소비심리           예측값
# 0       42225.806452   41958.333333  66024.390244  50489.978080
# 1       42225.806452   41958.333333  66024.390244  50261.671350
# 2       37411.290323   41958.333333  66024.390244  75510.691850
# 3       37411.290323   41958.333333  66024.390244  56030.711200
# 4       35806.451613   41958.333333  66024.390244  52753.071750
# ...              ...            ...           ...           ...
# 589721  55064.516129  100000.000000    500.000000  39516.805650
# 589722  82346.774194  100000.000000    500.000000   8253.709137
# 589723  58274.193548  100000.000000    500.000000  38933.638140
# 589724  58274.193548  100000.000000    500.000000  45406.121100
# 589725  58274.193548  100000.000000    500.000000  40059.422930
#
# [589726 rows x 9 columns]

# %%
result = pd.DataFrame({
  '계약년월': ['201601', '201602', '201603', '201604', '201605', '201606','201607', '201608', '201609','201610', '201611', '201612', 
                 '201701', '201702', '201703', '201704', '201705', '201706', '201707', '201708', '201709', '201710', '201711', '2001712',
                 '201801', '201802', '201803', '201804', '201805', '201806', '201807', '201808', '201809', '201810', '201811', '201812'],
  '실제값': [0.362120 * (100000.0-500.0)+500, 0.362120 * (100000.0-500.0)+500, 0.344907 * (100000.0-500.0)+500,
              0.346538 * (100000.0-500.0)+500, 0.348332 * (100000.0-500.0)+500, 0.359644 * (100000.0-500.0)+500,
              0.359922 * (100000.0-500.0)+500, 0.349641 * (100000.0-500.0)+500, 0.375077 * (100000.0-500.0)+500,
              0.385391 * (100000.0-500.0)+500, 0.392834 * (100000.0-500.0)+500, 0.407924 * (100000.0-500.0)+500,
              0.388006 * (100000.0-500.0)+500, 0.381477 * (100000.0-500.0)+500, 0.362019 * (100000.0-500.0)+500,
              0.385883 * (100000.0-500.0)+500, 0.380351 * (100000.0-500.0)+500, 0.381554 * (100000.0-500.0)+500,
              0.382213 * (100000.0-500.0)+500, 0.376631 * (100000.0-500.0)+500, 0.389992 * (100000.0-500.0)+500,
              0.390594 * (100000.0-500.0)+500, 0.408907 * (100000.0-500.0)+500, 0.415363 * (100000.0-500.0)+500,
              0.404829 * (100000.0-500.0)+500, 0.404563 * (100000.0-500.0)+500, 0.389124 * (100000.0-500.0)+500,
              0.390689 * (100000.0-500.0)+500, 0.398179 * (100000.0-500.0)+500, 0.403312 * (100000.0-500.0)+500,
              0.395421 * (100000.0-500.0)+500, 0.396978 * (100000.0-500.0)+500, 0.403635 * (100000.0-500.0)+500,
              0.417093 * (100000.0-500.0)+500, 0.424506 * (100000.0-500.0)+500, 0.433460 * (100000.0-500.0)+500 ],
  '예측값': [0.362928 * (100000.0-500.0)+500, 0.362928 * (100000.0-500.0)+500, 0.350313 * (100000.0-500.0)+500,
              0.350392 * (100000.0-500.0)+500, 0.350796 * (100000.0-500.0)+500, 0.359717 * (100000.0-500.0)+500,
              0.359572 * (100000.0-500.0)+500, 0.354626 * (100000.0-500.0)+500, 0.369621 * (100000.0-500.0)+500,
              0.377150 * (100000.0-500.0)+500, 0.386482 * (100000.0-500.0)+500, 0.405396 * (100000.0-500.0)+500,
              0.389289 * (100000.0-500.0)+500, 0.385223 * (100000.0-500.0)+500, 0.371034 * (100000.0-500.0)+500,
              0.388146 * (100000.0-500.0)+500, 0.378188 * (100000.0-500.0)+500, 0.378080 * (100000.0-500.0)+500,
              0.375286 * (100000.0-500.0)+500, 0.373243 * (100000.0-500.0)+500, 0.377112 * (100000.0-500.0)+500,
              0.380961 * (100000.0-500.0)+500, 0.397202 * (100000.0-500.0)+500, 0.405368 * (100000.0-500.0)+500,
              0.403733 * (100000.0-500.0)+500, 0.404138 * (100000.0-500.0)+500, 0.388530 * (100000.0-500.0)+500,
              0.390369 * (100000.0-500.0)+500, 0.403761 * (100000.0-500.0)+500, 0.403241 * (100000.0-500.0)+500,
              0.396706 * (100000.0-500.0)+500, 0.395304 * (100000.0-500.0)+500, 0.394079 * (100000.0-500.0)+500,
              0.406537 * (100000.0-500.0)+500, 0.413349 * (100000.0-500.0)+500, 0.422997 * (100000.0-500.0)+500 ]
})

# %%
result
# Out:
#        계약년월         실제값         예측값
# 0    201601  36530.9400  36611.3360
# 1    201602  36530.9400  36611.3360
# 2    201603  34818.2465  35356.1435
# 3    201604  34980.5310  35364.0040
# 4    201605  35159.0340  35404.2020
# 5    201606  36284.5780  36291.8415
# 6    201607  36312.2390  36277.4140
# 7    201608  35289.2795  35785.2870
# 8    201609  37820.1615  37277.2895
# 9    201610  38846.4045  38026.4250
# 10   201611  39586.9830  38954.9590
# 11   201612  41088.4380  40836.9020
# 12   201701  39106.5970  39234.2555
# 13   201702  38456.9615  38829.6885
# 14   201703  36520.8905  37417.8830
# 15   201704  38895.3585  39120.5270
# 16   201705  38344.9245  38129.7060
# 17   201706  38464.6230  38118.9600
# 18   201707  38530.1935  37840.9570
# 19   201708  37974.7845  37637.6785
# 20   201709  39304.2040  38022.6440
# 21   201710  39364.1030  38405.6195
# 22   201711  41186.2465  40021.5990
# 23  2001712  41828.6185  40834.1160
# 24   201801  40780.4855  40671.4335
# 25   201802  40754.0185  40711.7310
# 26   201803  39217.8380  39158.7350
# 27   201804  39373.5555  39341.7155
# 28   201805  40118.8105  40674.2195
# 29   201806  40629.5440  40622.4795
# 30   201807  39844.3895  39972.2470
# 31   201808  39999.3110  39832.7480
# 32   201809  40661.6825  39710.8605
# 33   201810  42000.7535  40950.4315
# 34   201811  42738.3470  41628.2255
# 35   201812  43629.2700  42588.2015

# %%
plt.plot(result['계약년월'], result['실제값'], label='real')
plt.plot(result['계약년월'], result['예측값'], label='predict')

plt.xlabel('period')
plt.ylabel('real')
plt.title('real vs predict')
plt.legend()

plt.show()
