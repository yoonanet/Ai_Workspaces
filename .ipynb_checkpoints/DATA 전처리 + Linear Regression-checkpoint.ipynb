# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import  LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# %%
# 밑에 '''''' 는 확인해보시고 쓸지안쓸지? 
# 상관분석도 어떤걸로 쓸건지? 
# 기존 df로 선택해서 갈건지 아니면 차원축소한 버전으로 갈건지?

# %% [markdown]
# # 데이터 불러오기

# %%
df = pd.read_csv('project2_data/apt161718.csv', low_memory=False, dtype={'status': 'category'})

# %% [markdown]
# # 데이터 EDA 및 전처리 1

# %% [markdown]
# # 분석에 맞는 데이터 필터링 & 컬럼 정리

# %%
df.head()
# 문자, 숫자 섞여 있는 데이터
# Out:
#              시군구     번지     본번   부번             단지명 전월세구분  전용면적(㎡)    계약년월  \
# 0  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    전세    79.97  201601
# 1  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    월세    79.97  201601
# 2  서울특별시 강남구 개포동  658-1  658.0  1.0  개포6차우성아파트1동~8동    전세    79.97  201601
# 3  서울특별시 강남구 개포동    652  652.0  0.0          개포우성3차    전세   133.46  201601
# 4  서울특별시 강남구 개포동    652  652.0  0.0          개포우성3차    전세   104.43  201601
#
#    계약일 보증금(만원)  ...  층  건축년도      도로명 계약기간 계약구분 갱신요구권 사용 종전계약 보증금 (만원)  \
# 0    7  44,000  ...  2  1987    언주로 3    -    -        -           NaN
# 1   16   5,000  ...  1  1987    언주로 3    -    -        -           NaN
# 2   21  42,000  ...  1  1987    언주로 3    -    -        -           NaN
# 3   12  80,000  ...  6  1984  개포로 307    -    -        -           NaN
# 4   15  52,000  ...  4  1984  개포로 307    -    -        -           NaN
#
#    종전계약 월세 (만원)   금리  부동산소비심리
# 0           NaN  1.5    117.6
# 1           NaN  1.5    117.6
# 2           NaN  1.5    117.6
# 3           NaN  1.5    117.6
# 4           NaN  1.5    117.6
#
# [5 rows x 21 columns]

# %%
df.shape
# 4,822,002 개의 레코드 데이터, 21개 컬럼
# Out:
# (482002, 21)

# %%
# 컬럼 : 시군구, 번지, 본번, 부번, 단지명, 전월세구분, 전용면적(㎡), 계약년월, 계약일, 보증금(만원), 월세(만원), 층, 건축년도, 도로명, 계약기간, 계약구분,
#         갱신요구권 사용, 종전계약 보증금 (만원), 종전계약 월세 (만원), 금리, 부동산소비심리


# 컬럼 중 시군구, 번지, 본번, 부번, 도로명은 서로 성격이 겹치는 컬럼이기에 하나로 대표할 수 있는 시군구 컬럼만 남김
# 컬럼 중 계약년월, 계약일 중 계약일 컬럼만 남김
# 알아내고자 하는 것이 보증금이기 때문에 계약기간(유효한 값이 거의 없기에 그냥 삭제하기로함), 계약구분, 개신요구권사용, 종전계약보증금(만원), 종전계약 월세(만원)은 삭제하여 활용하기로 함 
# 이중에서도 전세에 관한 것을 알기 위해 전월세구분에서 전세로 필터링해 활용함


# 단어 의미 확인하기
# 시군구 : 행정 구역인 시와 군, 구를 아울러 이르는 말
# 단지명 : 주택, 공장, 작물 재배지 따위가 집단을 이루고 있는 일정 구역의 이름
# 전세 : 부동산의 소유주에게 일정한 돈을 맡기고 집이나 방을 빌려 쓰다가, 내놓을 때 그 돈의 전액을 돌려받는 제도 
# 전용면적 : 아파트 따위의 공동 주택에서, 출입구나 엘리베이터, 계단 등의 공유 면적을 제외한 바닥 넓이
# 계약년월 : 계약을 진행한 연도와 월
# 보증금 : 입찰 또는 계약을 맺을 때 계약 이행의 담보로 내는 금전
# 층 : 건물의 층 
# 건축년도 : 건물 완공 년
# 금리 : 금융 기관에서 빌려준 돈이나 예금 따위에 대한 이율
# 부동산소비심리 : 부동산에서 반응하는 소비자들의 심리 수준, 형태 변화 및 인지 수준을 파악한 뒤 지수화한 값

# %%
#우리가 알고자 하는 주제는 전세이기 때문에 필터링 진행
df = df[df['전월세구분'] == '전세']


# 서울시 동별 보증금이 다를 것이라는 가설을 전제로 '동' 컬럼 추가
df['동'] = df['시군구'].str.replace('서울특별시', '')
#df = df[df['전월세구분'] == '전세']
remove_gu = ['서울특별시 ', '강남구 ', '강동구 ', '강북구 ', '강서구 ', '관악구 ', '광진구 ','구로구 ', '금천구 ', '노원구 ', '도봉구 ', '동대문구 ', '동작구 ', '마포구 ', '서대문구 ', '서초구 ', '성동구 ', '성북구 ','송파구 ' , '양천구 ', '영등포구 ', '용산구 ', '은평구 ', '종로구 ', '중구 ', '중랑구 ']
df['동'] = df['시군구'].str.replace('|'.join(remove_gu), '', regex=True)


#데이터 보기 편하게 재배열
df = df[['시군구', '동', '단지명','전월세구분','전용면적(㎡)','계약년월','층', '건축년도', '금리','부동산소비심리', '보증금(만원)']]


# 보증금(만원) 컬럼이 문자로 저장되어 있어 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(",", "").astype(int)


# 전용면적(㎡), 보증금(만원) 컬럼명에서 ()가 들어가 삭제함
df.rename(columns={'전용면적(㎡)': '전용면적'}, inplace=True)
df.rename(columns={'보증금(만원)': '보증금'}, inplace=True)

df.head()
# Out:
#              시군구    동             단지명 전월세구분    전용면적    계약년월  층  건축년도   금리  \
# 0  서울특별시 강남구 개포동  개포동  개포6차우성아파트1동~8동    전세   79.97  201601  2  1987  1.5
# 2  서울특별시 강남구 개포동  개포동  개포6차우성아파트1동~8동    전세   79.97  201601  1  1987  1.5
# 3  서울특별시 강남구 개포동  개포동          개포우성3차    전세  133.46  201601  6  1984  1.5
# 4  서울특별시 강남구 개포동  개포동          개포우성3차    전세  104.43  201601  4  1984  1.5
# 5  서울특별시 강남구 개포동  개포동          개포우성3차    전세  104.43  201601  1  1984  1.5
#
#    부동산소비심리    보증금
# 0    117.6  44000
# 2    117.6  42000
# 3    117.6  80000
# 4    117.6  52000
# 5    117.6  55000

# %% [markdown]
# # 각 컬럼에 대한 특징 파악하기

# %%
# 1) 피처(Feature) 확인
df.columns
# Out:
# Index(['시군구', '동', '단지명', '전월세구분', '전용면적', '계약년월', '층', '건축년도', '금리',
#        '부동산소비심리', '보증금'],
#       dtype='object')

# %%
# 2) 데이터 프레임 정보 확인
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 328695 entries, 0 to 482001
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   시군구      328695 non-null  object
#  1   동        328695 non-null  object
#  2   단지명      328695 non-null  object
#  3   전월세구분    328695 non-null  object
#  4   전용면적     328695 non-null  float64
#  5   계약년월     328695 non-null  int64
#  6   층        328695 non-null  int64
#  7   건축년도     328695 non-null  int64
#  8   금리       328695 non-null  float64
#  9   부동산소비심리  328695 non-null  float64
#  10  보증금      328695 non-null  int32
# dtypes: float64(3), int32(1), int64(3), object(4)
# memory usage: 28.8+ MB

# %%
# 3) 데이터 프레임 통계값 (전체)
df.describe()
# Out:
#                 전용면적           계약년월              층           건축년도  \
# count  328695.000000  328695.000000  328695.000000  328695.000000
# mean       77.441354  201712.013170       8.812784    1998.911894
# std        27.911234      82.077535       5.965429      10.767297
# min        10.110000  201601.000000      -2.000000    1961.000000
# 25%        59.730000  201610.000000       4.000000    1990.000000
# 50%        82.610000  201707.000000       8.000000    2000.000000
# 75%        84.970000  201804.000000      12.000000    2007.000000
# max       317.360000  201812.000000      68.000000    2022.000000
#
#                   금리        부동산소비심리            보증금
# count  328695.000000  328695.000000  328695.000000
# mean        1.389266     118.376674   41178.943623
# std         0.140425       9.000347   23630.392391
# min         1.250000      93.900000     500.000000
# 25%         1.250000     113.100000   26000.000000
# 50%         1.500000     119.200000   37000.000000
# 75%         1.500000     126.300000   50000.000000
# max         1.750000     134.100000  500000.000000

# %%
# 동 : 서울의 동을 나누었을 때 332개로 나누었으며(충무로1가, 장충동2가 등 포함) 가장 많은 거래(12,727건)가 상계동에서 있었다는 것을 알 수 있음
df.동.describe()
# Out:
# count     328695
# unique       332
# top          상계동
# freq       12727
# Name: 동, dtype: object

# %%
# 단지명 : 6735의 서로 다른 아파트들이 있다는 것을 알 수 있음 -> 아파트명이 많이 겹침
# 겹쳐진 아파트병을 하나로 합칠 것인가 고민 -> 동일명아파트인데도 지역에 따라 전세 가격이 1억3천, 5억 이런 식으로 같은 아파트명인데도 차이가 많이남
# 퍼포먼스가 많이 느리지만 우선은 감안하고 신뢰도 및 정화도 확보에 우선을 두고 우선은 진행하도록 함
# 하지만 이것보다 1.5배 이상 더 많아지는 경우에는 이름을 그루핑해 전처리해 퍼포먼스 올릴 필요 있음
df.단지명.describe()
# Out:
# count     328695
# unique      6735
# top           현대
# freq        2735
# Name: 단지명, dtype: object

# %%
df['단지명'].value_counts() 
# 아파트에 대한 전처리는 이후 보증금에 대한 이상치 확인 후 진행
# Out:
# 현대             2735
# 신동아            2541
# 은마             1956
# 두산             1943
# 우성             1784
#                ...
# 노블네스트             1
# 한마음(796-72)       1
# AndPra레지던스        1
# (743-10)          1
# 청계리버팰리스A          1
# Name: 단지명, Length: 6735, dtype: int64

# %%
# 전용면적 : 거래된 아파트 중 가장 작은 전용면적은 10.11(㎡), 가장 넓은 전용면적은 317.36(㎡) 임
df.전용면적.describe()
# Out:
# count    328695.000000
# mean         77.441354
# std          27.911234
# min          10.110000
# 25%          59.730000
# 50%          82.610000
# 75%          84.970000
# max         317.360000
# Name: 전용면적, dtype: float64

# %%
plt.hist(df['전용면적'], bins=10, facecolor='blue', alpha=0.5)
plt.show()
#대부분 50~100사이의 면적거래가 있었다는 것을 알 수 있음

# %%
# 계약년월 : 201601~201812 까지의 자료임을 알 수 있음
df.계약년월.describe()
# Out:
# count    328695.000000
# mean     201712.013170
# std          82.077535
# min      201601.000000
# 25%      201610.000000
# 50%      201707.000000
# 75%      201804.000000
# max      201812.000000
# Name: 계약년월, dtype: float64

# %%
# 층 : -2~68층까지 분포 (지하층이 있는지 확인)
df.층.describe()
# Out:
# count    328695.000000
# mean          8.812784
# std           5.965429
# min          -2.000000
# 25%           4.000000
# 50%           8.000000
# 75%          12.000000
# max          68.000000
# Name: 층, dtype: float64

# %%
#지하층 있는 곳 파악 , -1층, 19곳
df.loc[df['층']==-1]
# Out:
#                   시군구    동                        단지명 전월세구분      전용면적    계약년월  \
# 3055    서울특별시 관악구 남현동  남현동                      관악산센텀    전세   19.2600  201601
# 17025   서울특별시 구로구 천왕동  천왕동                  천왕연지타운1단지    전세   84.8700  201602
# 55843   서울특별시 구로구 천왕동  천왕동                  천왕연지타운2단지    전세   84.9900  201605
# 66190   서울특별시 관악구 남현동  남현동                      관악산센텀    전세   23.6200  201606
# 78219   서울특별시 관악구 남현동  남현동                      관악산센텀    전세   26.6700  201607
# 86899    서울특별시 중구 신당동  신당동                    글로리안(A)    전세   59.9000  201607
# 112158  서울특별시 용산구 동자동  동자동                         동자    전세   42.2300  201609
# 127543  서울특별시 용산구 이촌동  이촌동                         강변    전세   66.0800  201610
# 211613   서울특별시 중구 신당동  신당동                         하영    전세   59.6200  201704
# 223385  서울특별시 용산구 이촌동  이촌동                         강변    전세   66.0800  201705
# 332351  서울특별시 구로구 천왕동  천왕동                  천왕연지타운1단지    전세   84.8700  201802
# 421816  서울특별시 은평구 진관동  진관동  우물골2단지두산위브(223~244동)BL2-7    전세  101.9700  201808
# 423294  서울특별시 강남구 신사동  신사동                 RudenHouse    전세   73.2200  201809
# 435319  서울특별시 용산구 후암동  후암동                    삼안리치10차    전세   80.8200  201809
# 441388  서울특별시 구로구 천왕동  천왕동                  천왕연지타운2단지    전세   84.9900  201810
# 452251   서울특별시 중구 신당동  신당동                    글로리안(A)    전세   59.9000  201810
# 457303  서울특별시 금천구 시흥동  시흥동                      대도훼미리    전세   57.6900  201811
# 477179  서울특별시 성북구 길음동  길음동                   롯데캐슬골든힐스    전세   59.8946  201812
# 477180  서울특별시 성북구 길음동  길음동                   롯데캐슬골든힐스    전세   59.8946  201812
#
#         층  건축년도    금리  부동산소비심리    보증금
# 3055   -1  2013  1.50    117.6   6000
# 17025  -1  2013  1.50    120.1  27500
# 55843  -1  2014  1.50    126.4  41000
# 66190  -1  2013  1.25    126.6   8000
# 78219  -1  2013  1.25    128.8   5000
# 86899  -1  2002  1.25    128.8  14000
# 112158 -1  1969  1.25    127.4  10000
# 127543 -1  1971  1.25    128.7  13000
# 211613 -1  2002  1.25    119.2  14000
# 223385 -1  1971  1.25    126.2   9000
# 332351 -1  2013  1.50    126.3  29000
# 421816 -1  2010  1.50    127.5  46000
# 423294 -1  2007  1.50    126.2  16000
# 435319 -1  2005  1.50    126.2  27000
# 441388 -1  2014  1.50    115.1  48000
# 452251 -1  2002  1.50    115.1  16000
# 457303 -1  1991  1.50    106.5   9000
# 477179 -1  2019  1.75     93.9  34000
# 477180 -1  2019  1.75     93.9  34000

# %%
#지하층 있는 곳 파악 , -2층, 6곳
df.loc[df['층']==-2]
# Out:
#                   시군구    동                        단지명 전월세구분    전용면적    계약년월  \
# 140712  서울특별시 은평구 불광동  불광동                     불광롯데캐슬    전세   95.49  201611
# 155773  서울특별시 은평구 진관동  진관동  우물골2단지두산위브(223~244동)BL2-7    전세  134.48  201612
# 304072  서울특별시 구로구 천왕동  천왕동                  천왕연지타운1단지    전세   84.95  201712
# 417883  서울특별시 성동구 옥수동  옥수동            옥수파크힐스101동~116동    전세  107.99  201808
# 426587  서울특별시 구로구 천왕동  천왕동                  천왕연지타운2단지    전세   84.87  201809
# 476660  서울특별시 성동구 옥수동  옥수동            옥수파크힐스101동~116동    전세   76.66  201812
#
#         층  건축년도    금리  부동산소비심리     보증금
# 140712 -2  2013  1.25    113.8   57000
# 155773 -2  2010  1.25    102.8   45000
# 304072 -2  2013  1.50    114.8   40000
# 417883 -2  2016  1.50    127.5  104000
# 426587 -2  2014  1.50    126.2   43000
# 476660 -2  2016  1.75     93.9   75000

# %%
# 건축년도 : 1961년도~2022년도 신축까지 다양함
# 왜 16~18 전세 자료인데 건축년도가 22년이 나오는가?
# 장기계속공사의 경우 건설공사계약통계는 당해 연도 계약액을 기준으로 하고 있으며, 통계청 조사는 총 공사액을 기준으로 하고 있기 때문
df.건축년도.describe()
# Out:
# count    328695.000000
# mean       1998.911894
# std          10.767297
# min        1961.000000
# 25%        1990.000000
# 50%        2000.000000
# 75%        2007.000000
# max        2022.000000
# Name: 건축년도, dtype: float64

# %%
# 19년, 20년, 22년 건축년도와 계약년도를 맞춤
# 16~18 년도 계약이지만 건축년도가 미래에 있음. 그러나 전세 보증금의 기준은 계약년도였기 때문에 건축년도를 맞추어 데이터의 모순성 제거
search = df[(df['건축년도'] == 2019) & (df['계약년월'] == 201707)]
print(search)
# Out:
#                   시군구    동         단지명 전월세구분   전용면적    계약년월  층  건축년도    금리  \
# 239188  서울특별시 강북구 미아동  미아동  꿈의숲해링턴플레이스    전세  59.36  201707  8  2019  1.25
#
#         부동산소비심리    보증금
# 239188    134.1  60000

# %%
# 건축년도 2019년, 계약년월 201707 에 1건
# 건축년도 2019년, 계약년월 201712 에 1건
# 건축년도 2019년, 계약년월 201801 에 89건
# 건축년도 2019년, 계약년월 201802 에 71건
# 건축년도 2019년, 계약년월 201803 에 141건
# 건축년도 2019년, 계약년월 201804 에 118건
# 건축년도 2019년, 계약년월 201805 에 97건
# 건축년도 2019년, 계약년월 201806 에 120건
# 건축년도 2019년, 계약년월 201807 에 135건
# 건축년도 2019년, 계약년월 201808 에 118건
# 건축년도 2019년, 계약년월 201809 에 116건
# 건축년도 2019년, 계약년월 201810 에 129건
# 건축년도 2019년, 계약년월 201811 에 150건
# 건축년도 2019년, 계약년월 201812 에 278건
# ...

# %%
df.loc[(df['계약년월'].isin([201601, 201602, 201603, 201604, 201605, 201606, 201607, 201608, 201609, 201610, 201611, 201612])) & (df['건축년도'] == 2019), '건축년도'] = 2016
df.loc[(df['계약년월'].isin([201601, 201602, 201603, 201604, 201605, 201606, 201607, 201608, 201609, 201610, 201611, 201612])) & (df['건축년도'] == 2020), '건축년도'] = 2016
df.loc[(df['계약년월'].isin([201601, 201602, 201603, 201604, 201605, 201606, 201607, 201608, 201609, 201610, 201611, 201612])) & (df['건축년도'] == 2021), '건축년도'] = 2016
df.loc[(df['계약년월'].isin([201601, 201602, 201603, 201604, 201605, 201606, 201607, 201608, 201609, 201610, 201611, 201612])) & (df['건축년도'] == 2022), '건축년도'] = 2016

df.loc[(df['계약년월'].isin([201701, 201702, 201703, 201704, 201705, 201706, 201707, 201708, 201709, 201710, 201711, 201712])) & (df['건축년도'] == 2019), '건축년도'] = 2017
df.loc[(df['계약년월'].isin([201701, 201702, 201703, 201704, 201705, 201706, 201707, 201708, 201709, 201710, 201711, 201712])) & (df['건축년도'] == 2020), '건축년도'] = 2017
df.loc[(df['계약년월'].isin([201701, 201702, 201703, 201704, 201705, 201706, 201707, 201708, 201709, 201710, 201711, 201712])) & (df['건축년도'] == 2021), '건축년도'] = 2017
df.loc[(df['계약년월'].isin([201701, 201702, 201703, 201704, 201705, 201706, 201707, 201708, 201709, 201710, 201711, 201712])) & (df['건축년도'] == 2022), '건축년도'] = 2017

df.loc[(df['계약년월'].isin([201801, 201802, 201803, 201804, 201805, 201806, 201807, 201808, 201809, 201810, 201811, 201812])) & (df['건축년도'] == 2019), '건축년도'] = 2018
df.loc[(df['계약년월'].isin([201801, 201802, 201803, 201804, 201805, 201806, 201807, 201808, 201809, 201810, 201811, 201812])) & (df['건축년도'] == 2020), '건축년도'] = 2018
df.loc[(df['계약년월'].isin([201801, 201802, 201803, 201804, 201805, 201806, 201807, 201808, 201809, 201810, 201811, 201812])) & (df['건축년도'] == 2021), '건축년도'] = 2018
df.loc[(df['계약년월'].isin([201801, 201802, 201803, 201804, 201805, 201806, 201807, 201808, 201809, 201810, 201811, 201812])) & (df['건축년도'] == 2022), '건축년도'] = 2018

# %%
# 확인
search2 = df[(df['건축년도'] == 2019) & (df['계약년월'] == 201707)]
print(search2)
# Out:
# Empty DataFrame
# Columns: [시군구, 동, 단지명, 전월세구분, 전용면적, 계약년월, 층, 건축년도, 금리, 부동산소비심리, 보증금]
# Index: []

# %%
df
# Out:
#                   시군구    동             단지명 전월세구분    전용면적    계약년월   층  건축년도  \
# 0       서울특별시 강남구 개포동  개포동  개포6차우성아파트1동~8동    전세   79.97  201601   2  1987
# 2       서울특별시 강남구 개포동  개포동  개포6차우성아파트1동~8동    전세   79.97  201601   1  1987
# 3       서울특별시 강남구 개포동  개포동          개포우성3차    전세  133.46  201601   6  1984
# 4       서울특별시 강남구 개포동  개포동          개포우성3차    전세  104.43  201601   4  1984
# 5       서울특별시 강남구 개포동  개포동          개포우성3차    전세  104.43  201601   1  1984
# ...               ...  ...             ...   ...     ...     ...  ..   ...
# 481997  서울특별시 중랑구 중화동  중화동  한신아파트(103~109)    전세   59.76  201812  13  1997
# 481998  서울특별시 중랑구 중화동  중화동  한신아파트(103~109)    전세   84.03  201812   4  1997
# 481999  서울특별시 중랑구 중화동  중화동  한신아파트(103~109)    전세   50.37  201812  20  1997
# 482000  서울특별시 중랑구 중화동  중화동  한신아파트(103~109)    전세   59.76  201812  13  1997
# 482001  서울특별시 중랑구 중화동  중화동  한신아파트(103~109)    전세   59.76  201812   9  1997
#
#           금리  부동산소비심리    보증금
# 0       1.50    117.6  44000
# 2       1.50    117.6  42000
# 3       1.50    117.6  80000
# 4       1.50    117.6  52000
# 5       1.50    117.6  55000
# ...      ...      ...    ...
# 481997  1.75     93.9  28500
# 481998  1.75     93.9  34000
# 481999  1.75     93.9  27000
# 482000  1.75     93.9  29000
# 482001  1.75     93.9  29500
#
# [328695 rows x 11 columns]

# %%
# 보증금 : 제일 저렴한 것은 500만원, 비싼 것은 500000만원(50억.. ㅎ)이 나온다는 것을 알 수 있음 
df.보증금.describe()
# Out:
# count    328695.000000
# mean      41178.943623
# std       23630.392391
# min         500.000000
# 25%       26000.000000
# 50%       37000.000000
# 75%       50000.000000
# max      500000.000000
# Name: 보증금, dtype: float64

# %%
#저렴한 곳 : 500만원
df.loc[df['보증금']==500]
# Out:
#                   시군구    동        단지명 전월세구분   전용면적    계약년월   층  건축년도    금리  \
# 116727  서울특별시 강서구 화곡동  화곡동      아델리아Ⅰ    전세  10.92  201610   4  2012  1.25
# 330417  서울특별시 강서구 가양동  가양동  가양2단지(성지)    전세  49.56  201802  14  1992  1.50
# 349063  서울특별시 도봉구 방학동  방학동    방학지음재힐스    전세  14.79  201803   3  2018  1.50
# 362478  서울특별시 구로구 오류동  오류동   오류동역솔리스타    전세  19.27  201804   7  2016  1.50
# 376005  서울특별시 도봉구 방학동  방학동    방학지음재힐스    전세  14.86  201805   3  2018  1.50
# 452175  서울특별시 종로구 창신동  창신동        동대문    전세  28.80  201810   5  1966  1.50
#
#         부동산소비심리  보증금
# 116727    128.7  500
# 330417    126.3  500
# 349063    116.3  500
# 362478    108.3  500
# 376005    109.8  500
# 452175    115.1  500

# %%
#비싼곳 : 50억원
df.loc[df['보증금']==500000]
# Out:
#                     시군구      동     단지명 전월세구분    전용면적    계약년월   층  건축년도   금리  \
# 461738  서울특별시 성동구 성수동1가  성수동1가  갤러리아포레    전세  271.38  201811  44  2011  1.5
#
#         부동산소비심리     보증금
# 461738    106.5  500000

# %%
plt.hist(df['보증금'], bins=10, facecolor='blue', alpha=0.5)
plt.show()
# 10억이하, 5억 이하 주위로 많이 분포되어 있음을 알 수 있음

# %%
plt.boxplot(df['보증금'])
plt.show()

# %%
# 누가봐도 10억 이상은 안될 것 같은 그래프 나옴
# 10억 이상의 데이터를 이상치로 잡고 제거 or 평균화 -> 제거

# %%
# 보증금이 10억 이상인 데이터 카운트
df_10억 = df[df['보증금'] > 100000]
print(df_10억)
# Out:
#                     시군구      동          단지명 전월세구분     전용면적    계약년월   층  건축년도  \
# 300       서울특별시 강남구 논현동    논현동        동양파라곤    전세  208.350  201601   4  2004
# 331       서울특별시 강남구 대치동    대치동        개포우성1    전세  127.610  201601  10  1983
# 332       서울특별시 강남구 대치동    대치동        개포우성1    전세  158.540  201601   1  1983
# 336       서울특별시 강남구 대치동    대치동        개포우성1    전세  127.610  201601  11  1983
# 345       서울특별시 강남구 대치동    대치동        개포우성2    전세  127.780  201601   9  1984
# ...                 ...    ...          ...   ...      ...     ...  ..   ...
# 480889    서울특별시 용산구 이촌동    이촌동      래미안첼리투스    전세  124.350  201812   6  2015
# 480991  서울특별시 용산구 한강로3가  한강로3가  용산시티파크(1단지)    전세  181.890  201812   4  2007
# 481012    서울특별시 용산구 한남동    한남동      현대하이페리온    전세  225.130  201812  12  2002
# 481564    서울특별시 종로구 홍파동    홍파동   경희궁자이(2단지)    전세  116.986  201812  10  2017
# 481569    서울특별시 종로구 홍파동    홍파동   경희궁자이(2단지)    전세  116.986  201812   8  2017
#
#           금리  부동산소비심리     보증금
# 300     1.50    117.6  130000
# 331     1.50    117.6  107000
# 332     1.50    117.6  105000
# 336     1.50    117.6  103000
# 345     1.50    117.6  105000
# ...      ...      ...     ...
# 480889  1.75     93.9  150000
# 480991  1.75     93.9  120000
# 481012  1.75     93.9  150000
# 481564  1.75     93.9  110000
# 481569  1.75     93.9  115000
#
# [7716 rows x 11 columns]

# %%
# 보증금이 5억 이상인 데이터 카운트
df_5억 = df[df['보증금'] >= 50000]
print(df_5억)
# Out:
#                   시군구    동        단지명 전월세구분      전용면적    계약년월   층  건축년도    금리  \
# 3       서울특별시 강남구 개포동  개포동     개포우성3차    전세  133.4600  201601   6  1984  1.50
# 4       서울특별시 강남구 개포동  개포동     개포우성3차    전세  104.4300  201601   4  1984  1.50
# 5       서울특별시 강남구 개포동  개포동     개포우성3차    전세  104.4300  201601   1  1984  1.50
# 161     서울특별시 강남구 개포동  개포동    개포주공5단지    전세   74.2500  201601  12  1983  1.50
# 162     서울특별시 강남구 개포동  개포동    개포주공5단지    전세   74.2500  201601  13  1983  1.50
# ...               ...  ...        ...   ...       ...     ...  ..   ...   ...
# 481835   서울특별시 중랑구 묵동   묵동  묵동자이(2단지)    전세  101.9000  201812  34  2010  1.75
# 481836   서울특별시 중랑구 묵동   묵동    브라운스톤태릉    전세  101.9481  201812  14  2004  1.75
# 481850   서울특별시 중랑구 묵동   묵동    신내대림아파트    전세  126.2800  201812   9  1995  1.75
# 481876  서울특별시 중랑구 상봉동  상봉동    상봉듀오트리스    전세  131.8000  201812   5  2016  1.75
# 481905  서울특별시 중랑구 상봉동  상봉동    프레미어스엠코    전세  107.1200  201812  17  2013  1.75
#
#         부동산소비심리    보증금
# 3         117.6  80000
# 4         117.6  52000
# 5         117.6  55000
# 161       117.6  51000
# 162       117.6  50000
# ...         ...    ...
# 481835     93.9  55000
# 481836     93.9  55000
# 481850     93.9  50000
# 481876     93.9  65000
# 481905     93.9  57000
#
# [90337 rows x 11 columns]

# %%
# 전체 328,695 건 중 10억 초과인 경우 : 7,716건 -> 전체의 약 2.3%

# %%
# 전체 328,695 건 중 5억 이상인 경우 : 90,337건 -> 전체의 약 27.4%

# %%
# 3분위수 이상값(5억이상)을 이상치로 잡을 것인가 vs 10이상을 이상치로 잡을 것인가
# 값에 영향을 많이 받지 않도록 10억 이상의 값을 이상치로 잡아 하는 것으로??

# %% [markdown]
# # 값에 영향을 많이 받지 않도록 10억 이상의 값을 이상치로 잡아 하는 것으로??

# %% [markdown]
# # 값은 삭제할 것인지 아니면 평균값(또는 중간값)으로 넣을 것인지? 아니면 최대값으로 잡은 10억으로 잡을 것인지?, 비싼 것을 평균값으로 넣는것은 신뢰도가 떨어지고 최대값으로 넣으면 10억 자체가 이상치로 발견될 수 있기에 그냥 삭제하자.

# %%
# 삭제진행

# 필터
df = df[df['보증금'] <= 100000]

# 이상치 데이터 삭제 후 확인 : 최대 10억, 최소 500, 중간값 3억7천, 평균값 3억 9천
df.describe()
# Out:
#                 전용면적           계약년월              층           건축년도  \
# count  320979.000000  320979.000000  320979.000000  320979.000000
# mean       76.076619  201711.545668       8.691213    1998.759458
# std        26.141417      82.104811       5.780531      10.723342
# min        10.110000  201601.000000      -2.000000    1961.000000
# 25%        59.680000  201610.000000       4.000000    1990.000000
# 50%        80.920000  201707.000000       8.000000    1999.000000
# 75%        84.960000  201804.000000      12.000000    2007.000000
# max       317.360000  201812.000000      66.000000    2018.000000
#
#                   금리        부동산소비심리            보증금
# count  320979.000000  320979.000000  320979.000000
# mean        1.388802     118.405118   39010.146888
# std         0.140256       8.987102   18613.787295
# min         1.250000      93.900000     500.000000
# 25%         1.250000     113.100000   26000.000000
# 50%         1.500000     119.200000   37000.000000
# 75%         1.500000     126.300000   50000.000000
# max         1.750000     134.100000  100000.000000

# %%
# 아파트별 가격 평균 내림차순으로 정렬
apt_price = df.groupby('단지명')['보증금'].agg('mean').sort_values(ascending=False)
print('변환전\n', apt_price[:5])
# Out:
# 변환전
#  단지명
# ThePlusⅢ     100000.0
# 장충동라임카운티     100000.0
# 삼성서초가든스위트    100000.0
# 서초8차상지리츠빌    100000.0
# 상지리츠빌6       100000.0
# Name: 보증금, dtype: float64

# %%
df.head()
# Out:
#              시군구    동             단지명 전월세구분    전용면적    계약년월  층  건축년도   금리  \
# 0  서울특별시 강남구 개포동  개포동  개포6차우성아파트1동~8동    전세   79.97  201601  2  1987  1.5
# 2  서울특별시 강남구 개포동  개포동  개포6차우성아파트1동~8동    전세   79.97  201601  1  1987  1.5
# 3  서울특별시 강남구 개포동  개포동          개포우성3차    전세  133.46  201601  6  1984  1.5
# 4  서울특별시 강남구 개포동  개포동          개포우성3차    전세  104.43  201601  4  1984  1.5
# 5  서울특별시 강남구 개포동  개포동          개포우성3차    전세  104.43  201601  1  1984  1.5
#
#    부동산소비심리    보증금
# 0    117.6  44000
# 2    117.6  42000
# 3    117.6  80000
# 4    117.6  52000
# 5    117.6  55000

# %%
#가격별로 0~ 인코딩 해주기
for i, a in enumerate(list(apt_price.index)):
    df.loc[df['단지명'] == a, '단지명'] = i 
apt_price = df.groupby('단지명')['보증금'].agg('mean').sort_values(ascending=False)
print('변환후\n', apt_price[:5])
# Out:
# 변환후
#  단지명
# 0     100000.0
# 12    100000.0
# 22    100000.0
# 21    100000.0
# 20    100000.0
# Name: 보증금, dtype: float64

# %%
# 완공연도에서 최소연도 빼서 완공연도 라벨인코딩
print('변환전\n', df['건축년도'].unique()[:5])
df['건축년도'] = df['건축년도'] - df['건축년도'].min()
print('변환후\n', df['건축년도'].unique()[:5])
# Out:
# 변환전
#  [1987 1984 1982 1983 1993]
# 변환후
#  [26 23 21 22 32]
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_2036\1337691090.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['건축년도'] = df['건축년도'] - df['건축년도'].min()

# %%
# 연월 증가하는 순으로 라벨 인코딩 : 계약년월
le = LabelEncoder()
df['계약년월'] = le.fit_transform(df['계약년월'])
print('변환후\n', df['계약년월'].unique()[:5])
# Out:
# 변환후
#  [0 1 2 3 4]
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_2036\3528694067.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['계약년월'] = le.fit_transform(df['계약년월'])

# %%
# 중간 확인
df.head()
# Out:
#              시군구    동   단지명 전월세구분    전용면적  계약년월  층  건축년도   금리  부동산소비심리    보증금
# 0  서울특별시 강남구 개포동  개포동  2059    전세   79.97     0  2    26  1.5    117.6  44000
# 2  서울특별시 강남구 개포동  개포동  2059    전세   79.97     0  1    26  1.5    117.6  42000
# 3  서울특별시 강남구 개포동  개포동   453    전세  133.46     0  6    23  1.5    117.6  80000
# 4  서울특별시 강남구 개포동  개포동   453    전세  104.43     0  4    23  1.5    117.6  52000
# 5  서울특별시 강남구 개포동  개포동   453    전세  104.43     0  1    23  1.5    117.6  55000

# %%
# 동 인코딩하기

#동 EDA
dong_price = df.groupby('동')['보증금'].agg('mean').sort_values(ascending=False)
dong_price[:20]

#현재 데이터에서는 가장 비싼 동은 장충동1가 (10억 필터링 전에는 용산구5가였음)
# Out:
# 동
# 장충동1가     100000.000000
# 회현동2가      95375.000000
# 용산동5가      87314.814815
# 하중동        83994.047619
# 청암동        82967.741935
# 남대문로5가     82166.666667
# 홍파동        80466.666667
# 견지동        79250.000000
# 내수동        78258.620690
# 평동         74825.000000
# 성북동1가      74000.000000
# 사직동        73834.210526
# 회현동1가      69073.913043
# 동빙고동       65454.545455
# 동자동        65141.304348
# 상왕십리동      65087.505051
# 신계동        64164.876847
# 한강로1가      63576.923077
# 상수동        63441.880851
# 압구정동       63200.583224
# Name: 보증금, dtype: float64

# %%
# 동별 인코딩 (평균값 비싼순서대로~)
for i, d in enumerate(list(dong_price.index)):
    df.loc[df['동'] == d, '동'] = i

df
# Out:
#                   시군구    동   단지명 전월세구분    전용면적  계약년월   층  건축년도    금리  부동산소비심리  \
# 0       서울특별시 강남구 개포동  165  2059    전세   79.97     0   2    26  1.50    117.6
# 2       서울특별시 강남구 개포동  165  2059    전세   79.97     0   1    26  1.50    117.6
# 3       서울특별시 강남구 개포동  165   453    전세  133.46     0   6    23  1.50    117.6
# 4       서울특별시 강남구 개포동  165   453    전세  104.43     0   4    23  1.50    117.6
# 5       서울특별시 강남구 개포동  165   453    전세  104.43     0   1    23  1.50    117.6
# ...               ...  ...   ...   ...     ...   ...  ..   ...   ...      ...
# 481997  서울특별시 중랑구 중화동  241  3890    전세   59.76    35  13    36  1.75     93.9
# 481998  서울특별시 중랑구 중화동  241  3890    전세   84.03    35   4    36  1.75     93.9
# 481999  서울특별시 중랑구 중화동  241  3890    전세   50.37    35  20    36  1.75     93.9
# 482000  서울특별시 중랑구 중화동  241  3890    전세   59.76    35  13    36  1.75     93.9
# 482001  서울특별시 중랑구 중화동  241  3890    전세   59.76    35   9    36  1.75     93.9
#
#           보증금
# 0       44000
# 2       42000
# 3       80000
# 4       52000
# 5       55000
# ...       ...
# 481997  28500
# 481998  34000
# 481999  27000
# 482000  29000
# 482001  29500
#
# [320979 rows x 11 columns]

# %%
# 층 수 확인 
# 최소값이 -2이므로 2를 더해서 음수를 없애고 순서형 범주 처리
# -2, -1, 1, 2와 같은 숫자와 함께 "층"이라는 레이블이 있음
# 머신러닝 모델이 층수를 이해하기 위해서는 층수를 숫자만으로 변환하는 것뿐만 아니라 레이블의 변환도 필요
print('변환전\n', df['층'].values[:5])
df['층'] = df['층'].map(lambda x: x+2)
print('변환후\n', df['층'].values[:5])
# Out:
# 변환전
#  [2 1 6 4 1]
# 변환후
#  [4 3 8 6 3]
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_2036\2000174731.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['층'] = df['층'].map(lambda x: x+2)

# %%
# 시군구,전세,apt_counts,transformed 컬럼 삭제
df = df.drop(['시군구', '전월세구분'], axis=1)
df.head()
# Out:
#      동   단지명    전용면적  계약년월  층  건축년도   금리  부동산소비심리    보증금
# 0  165  2059   79.97     0  4    26  1.5    117.6  44000
# 2  165  2059   79.97     0  3    26  1.5    117.6  42000
# 3  165   453  133.46     0  8    23  1.5    117.6  80000
# 4  165   453  104.43     0  6    23  1.5    117.6  52000
# 5  165   453  104.43     0  3    23  1.5    117.6  55000

# %%
df.shape
# Out:
# (320979, 9)

# %% [markdown]
# # 변수 살펴보기

# %% [markdown]
# # 상관분석
# ### -1~1 값, 0으로 가까울수록 관계없음, -1과 1로 갈 수록 음과 양의 관계 있음

# %%
# 상관분석1: 상관 관계 행렬

df_copy = df.copy()

# 분석 보기 편하기 위해 컬럼명 변경
df_copy = df_copy[['동', '단지명', '전용면적', '계약년월', '층', '건축년도', '부동산소비심리','금리','보증금']]
df_copy.columns = ['dong', 'apt_name', 'area', 'contract_month', 'floor', 'construction_year', 'psychology','interest','deposit']


#범주화된 항목 카테고리화 하기
df_copy['dong'] = df_copy['dong'].astype('category').cat.codes
df_copy['apt_name'] = df_copy['apt_name'].astype('category').cat.codes

#상관관계 행렬
df_corr=df_copy.corr()

#히트맵
plt.figure(figsize=(10,10))
sns.set(font_scale=0.8)
sns.heatmap(df_corr, annot=True, cmap="viridis")
plt.show()

# %%
# 보증금과 상관관계가 높은 순으로 출력하기
corr_order = df_copy.corr()['deposit'].abs().sort_values(ascending=False)
corr_order
# Out:
# deposit              1.000000
# apt_name             0.801835
# dong                 0.640357
# area                 0.636009
# construction_year    0.183327
# floor                0.169665
# contract_month       0.097679
# psychology           0.058243
# interest             0.043144
# Name: deposit, dtype: float64

# %%
print(df_corr)
# Out:
#                        dong  apt_name      area  contract_month     floor  \
# dong               1.000000  0.669699 -0.269445       -0.031735 -0.066264
# apt_name           0.669699  1.000000 -0.502293       -0.044139 -0.163719
# area              -0.269445 -0.502293  1.000000       -0.024008  0.037183
# contract_month    -0.031735 -0.044139 -0.024008        1.000000  0.023106
# floor             -0.066264 -0.163719  0.037183        0.023106  1.000000
# construction_year -0.015988 -0.204665 -0.023178        0.085784  0.192703
# psychology         0.039504  0.042298 -0.000731       -0.380587 -0.013966
# interest          -0.007476 -0.014261 -0.012650        0.478197  0.011505
# deposit           -0.640357 -0.801835  0.636009        0.097679  0.169665
#
#                    construction_year  psychology  interest   deposit
# dong                       -0.015988    0.039504 -0.007476 -0.640357
# apt_name                   -0.204665    0.042298 -0.014261 -0.801835
# area                       -0.023178   -0.000731 -0.012650  0.636009
# contract_month              0.085784   -0.380587  0.478197  0.097679
# floor                       0.192703   -0.013966  0.011505  0.169665
# construction_year           1.000000   -0.032443  0.050227  0.183327
# psychology                 -0.032443    1.000000 -0.361296 -0.058243
# interest                    0.050227   -0.361296  1.000000  0.043144
# deposit                     0.183327   -0.058243  0.043144  1.000000

# %%
# psychology와 interest 간의 상관관계가 높음
# psychology와 interest 중 하나를 제거 가능

# %%
# 상관분석2 :  선형회귀로 확인하기
# 시각화로 상관분석할 피처 정하기1 : deposit 중심
plot_cols = ['deposit', 'area','floor','construction_year','contract_month','psychology','interest']
plot_df = df_copy.loc[:, plot_cols]

plot_df.head()
# Out:
#    deposit    area  floor  construction_year  contract_month  psychology  \
# 0    44000   79.97      4                 26               0       117.6
# 2    42000   79.97      3                 26               0       117.6
# 3    80000  133.46      8                 23               0       117.6
# 4    52000  104.43      6                 23               0       117.6
# 5    55000  104.43      3                 23               0       117.6
#
#    interest
# 0       1.5
# 2       1.5
# 3       1.5
# 4       1.5
# 5       1.5

# %%
# regplot으로 선형회귀선 표시하기

plt.figure(figsize=(10, 10))
for idx, col in enumerate(plot_cols[1:]):
    ax1 = plt.subplot(4, 2, idx + 1)
    sns.regplot(x=col, y=plot_cols[0], data=plot_df, ax=ax1, color='gray', line_kws={'color': 'red'})
plt.tight_layout()
plt.show()

# %%
# 보증금과 비교했을 시
# 면적, 층, 계약년도은 양의 상관관계가 있음
# 건축년도, 금리, 심리 : 미약한 상관관계가 보임

# %%
# 피처별로 살펴보기
# 면적(area)와 다른 변수간의 관계
plot_cols = ['area', 'deposit', 'floor','construction_year','contract_month','psychology','interest']
plt.figure(figsize=(10, 10))
for idx, col in enumerate(plot_cols[1:]):
    ax1 = plt.subplot(4, 2, idx + 1)
    sns.regplot(x=col, y=plot_cols[0], data=plot_df, ax=ax1, color='gray', line_kws={'color': 'red'})
plt.tight_layout()
plt.show()

# %%
'''
# 피처별로 살펴보기
# 층(floor)와 다른 변수간의 관계
plot_cols = ['floor', 'area', 'deposit', 'construction_year', 'contract_month', 'interest', 'psychology']

plt.figure(figsize=(10, 10))
for idx, col in enumerate(plot_cols[1:]):
    ax1 = plt.subplot(4, 2, idx + 1)
    sns.regplot(x=col, y='floor', data=df, ax=ax1, color='gray', line_kws={'color': 'red'})
plt.tight_layout()
plt.show()
'''
# Out:
# "\n# 피처별로 살펴보기\n# 층(floor)와 다른 변수간의 관계\nplot_cols = ['floor', 'area', 'deposit', 'construction_year', 'contract_month', 'interest', 'psychology']\n\nplt.figure(figsize=(10, 10))\nfor idx, col in enumerate(plot_cols[1:]):\n    ax1 = plt.subplot(4, 2, idx + 1)\n    sns.regplot(x=col, y='floor', data=df, ax=ax1, color='gray', line_kws={'color': 'red'})\nplt.tight_layout()\nplt.show()\n"

# %%
'''
# 피처별로 살펴보기
# 건축년도(construction_year)와 다른 변수간의 관계
plot_cols = ['construction_year', 'area', 'deposit', 'floor','contract_month','psychology','interest']
plt.figure(figsize=(10, 10))
for idx, col in enumerate(plot_cols[1:]):
    ax1 = plt.subplot(4, 2, idx + 1)
    sns.regplot(x=col, y=plot_cols[0], data=df, ax=ax1, color='gray', line_kws={'color': 'red'})
plt.tight_layout()
plt.show()
'''
# Out:
# "\n# 피처별로 살펴보기\n# 건축년도(construction_year)와 다른 변수간의 관계\nplot_cols = ['construction_year', 'area', 'deposit', 'floor','contract_month','psychology','interest']\nplt.figure(figsize=(10, 10))\nfor idx, col in enumerate(plot_cols[1:]):\n    ax1 = plt.subplot(4, 2, idx + 1)\n    sns.regplot(x=col, y=plot_cols[0], data=df, ax=ax1, color='gray', line_kws={'color': 'red'})\nplt.tight_layout()\nplt.show()\n"

# %%
'''
# 피처별로 살펴보기
# 계약년월(contract_month)와 다른 변수간의 관계
plot_cols = ['contract_month', 'construction_year', 'area', 'deposit', 'floor','psychology','interest']
plt.figure(figsize=(10, 10))
for idx, col in enumerate(plot_cols[1:]):
    ax1 = plt.subplot(4, 2, idx + 1)
    sns.regplot(x=col, y=plot_cols[0], data=df, ax=ax1, color='gray', line_kws={'color': 'red'})
plt.tight_layout()
plt.show()
'''
# Out:
# "\n# 피처별로 살펴보기\n# 계약년월(contract_month)와 다른 변수간의 관계\nplot_cols = ['contract_month', 'construction_year', 'area', 'deposit', 'floor','psychology','interest']\nplt.figure(figsize=(10, 10))\nfor idx, col in enumerate(plot_cols[1:]):\n    ax1 = plt.subplot(4, 2, idx + 1)\n    sns.regplot(x=col, y=plot_cols[0], data=df, ax=ax1, color='gray', line_kws={'color': 'red'})\nplt.tight_layout()\nplt.show()\n"

# %%
'''
# 피처별로 살펴보기
# 부동산소비심리(psychology)와 다른 변수간의 관계
plot_cols = ['psychology', 'contract_month', 'construction_year', 'area', 'deposit', 'floor','interest']
plt.figure(figsize=(10, 10))
for idx, col in enumerate(plot_cols[1:]):
    ax1 = plt.subplot(4, 2, idx + 1)
    sns.regplot(x=col, y=plot_cols[0], data=df, ax=ax1, color='gray', line_kws={'color': 'red'})
plt.tight_layout()
plt.show()
'''
# Out:
# "\n# 피처별로 살펴보기\n# 부동산소비심리(psychology)와 다른 변수간의 관계\nplot_cols = ['psychology', 'contract_month', 'construction_year', 'area', 'deposit', 'floor','interest']\nplt.figure(figsize=(10, 10))\nfor idx, col in enumerate(plot_cols[1:]):\n    ax1 = plt.subplot(4, 2, idx + 1)\n    sns.regplot(x=col, y=plot_cols[0], data=df, ax=ax1, color='gray', line_kws={'color': 'red'})\nplt.tight_layout()\nplt.show()\n"

# %%
'''
# 피처별로 살펴보기
# 금리(interest)와 다른 변수간의 관계
plot_cols = ['interest','psychology', 'contract_month', 'construction_year', 'area', 'deposit', 'floor']
plt.figure(figsize=(10, 10))
for idx, col in enumerate(plot_cols[1:]):
    ax1 = plt.subplot(4, 2, idx + 1)
    sns.regplot(x=col, y=plot_cols[0], data=df, ax=ax1, color='gray', line_kws={'color': 'red'})
plt.tight_layout()
plt.show()
'''
# Out:
# "\n# 피처별로 살펴보기\n# 금리(interest)와 다른 변수간의 관계\nplot_cols = ['interest','psychology', 'contract_month', 'construction_year', 'area', 'deposit', 'floor']\nplt.figure(figsize=(10, 10))\nfor idx, col in enumerate(plot_cols[1:]):\n    ax1 = plt.subplot(4, 2, idx + 1)\n    sns.regplot(x=col, y=plot_cols[0], data=df, ax=ax1, color='gray', line_kws={'color': 'red'})\nplt.tight_layout()\nplt.show()\n"

# %%
# 상관분석3 : 스피어만 상관계수로 확인해보기
# 두 변수가 선형적으로 관련되어 있을때 보는 상관분석

# %%
df_copy = df.copy()
df_copy = df_copy[['동', '단지명', '전용면적', '계약년월', '층', '건축년도', '부동산소비심리','금리','보증금']]
df_copy.columns = ['dong', 'apt_name', 'area', 'contract_month', 'floor', 'construction_year', 'psychology','interest','deposit']

# 범주형 변수 순위 변수로 변환
df_copy['dong'] = df_copy['dong'].astype('category').cat.codes
df_copy['apt_name'] = df_copy['apt_name'].astype('category').cat.codes

# 스피어만 상관계수 계산
r = df_copy.corr(method='spearman')

# 스피어만 상관계수를 출력
print(r)

# 스피어만 상관계수 읽는 방법
# 1에 가까울수록 두 변수 간의 상관관계가 강하고, -1에 가까울수록 두 변수 간의 상관관계가 약함 (설사약과 변비약)
# 스피어만 상관계수 값이 0에 가까울수록 두 변수 간의 상관관계가 없음
# Out:
#                        dong  apt_name      area  contract_month     floor  \
# dong               1.000000  0.690088 -0.275989       -0.030414 -0.040710
# apt_name           0.690088  1.000000 -0.518161       -0.046170 -0.128646
# area              -0.275989 -0.518161  1.000000       -0.009746  0.039812
# contract_month    -0.030414 -0.046170 -0.009746        1.000000  0.021122
# floor             -0.040710 -0.128646  0.039812        0.021122  1.000000
# construction_year -0.036632 -0.228709  0.100911        0.082662  0.156410
# psychology         0.033698  0.039514 -0.005822       -0.375446 -0.010257
# interest          -0.002780 -0.011042 -0.003851        0.474867  0.009498
# deposit           -0.654327 -0.856490  0.670460        0.099308  0.137270
#
#                    construction_year  psychology  interest   deposit
# dong                       -0.036632    0.033698 -0.002780 -0.654327
# apt_name                   -0.228709    0.039514 -0.011042 -0.856490
# area                        0.100911   -0.005822 -0.003851  0.670460
# contract_month              0.082662   -0.375446  0.474867  0.099308
# floor                       0.156410   -0.010257  0.009498  0.137270
# construction_year           1.000000   -0.026450  0.046171  0.210330
# psychology                 -0.026450    1.000000 -0.263850 -0.054136
# interest                    0.046171   -0.263850  1.000000  0.036294
# deposit                     0.210330   -0.054136  0.036294  1.000000

# %%
# 행렬의 다른 상관 관계는 모두 비교적 약하며, 대부분은 통계적으로 유의하지 않음
# 이는 데이터 세트의 다른 변수 쌍 사이에는 강한 관계가 없다는 것을 의미함
# 물론, area와 deposit과의 사이에는 강한 상관관계가 보이지만 area가 학습 변수가 될 예정이기 때문에 논외로 침

# %%
# 히트맵으로 확인
plt.imshow(r)
plt.xticks(np.arange(len(r.columns)), r.columns, rotation='vertical')
plt.yticks(np.arange(len(r.columns)), r.columns)
plt.colorbar()
plt.show()

# %%
# 산점도로 확인하기
'''
plt.figure(figsize=(10, 10))
for idx, col in enumerate(plot_cols[1:]):
  ax1 = plt.subplot(4, 2, idx + 1)
  sns.regplot(x=col, y=plot_cols[0], data=plot_df, ax=ax1, color='gray', line_kws={'color': 'red'})
  ax1.text(x=0, y=1, s='Spearman correlation: {0:.3f}'.format(plot_df[col].corr(plot_df['deposit'], method='spearman')))
plt.tight_layout()
plt.show()
'''
# Out:
# "\nplt.figure(figsize=(10, 10))\nfor idx, col in enumerate(plot_cols[1:]):\n  ax1 = plt.subplot(4, 2, idx + 1)\n  sns.regplot(x=col, y=plot_cols[0], data=plot_df, ax=ax1, color='gray', line_kws={'color': 'red'})\n  ax1.text(x=0, y=1, s='Spearman correlation: {0:.3f}'.format(plot_df[col].corr(plot_df['deposit'], method='spearman')))\nplt.tight_layout()\nplt.show()\n"

# %% [markdown]
# # 변수 간 연관분석 - 주성분분석

# %%
# PCA를 수행 데이터
df_copy = df.copy()
df_copy = df_copy[['동', '단지명', '전용면적', '계약년월', '층', '건축년도', '부동산소비심리','금리','보증금']]
df_copy.columns = ['dong', 'apt_name', 'area', 'contract_month', 'floor', 'construction_year', 'psychology','interest','deposit']

# PCA를 수행
pca = PCA()
pca.fit(df_copy)

# PCA 결과 해석
print(pca.explained_variance_ratio_)
# Out:
# [9.97114940e-01 2.87128780e-03 1.17492797e-05 1.12346139e-06
#  3.68433117e-07 2.82259752e-07 1.60275183e-07 8.86594431e-08
#  4.13003134e-11]

# %%
# 첫 번째 주성분이 데이터의 99.97%의 분산을 설명

# %%
'''
from sklearn.decomposition import PCA

# 주성분을 pcs 변수에 저장. 주성분은 데이터의 주요 변수
pcs = pca.components_

# 주성분이 설명하는 분산을 var_explained 변수에 저장(분산: 데이터의 다양성)
var_explained = pca.explained_variance_ratio_

# 분산이 90% 이상인 주성분만을 선택하여 pcs 변수에 저장
pcs = pcs[:, var_explained > 0.9]
reduced_df = pca.transform(df_copy)
'''
# Out:
# '\nfrom sklearn.decomposition import PCA\n\n# 주성분을 pcs 변수에 저장. 주성분은 데이터의 주요 변수\npcs = pca.components_\n\n# 주성분이 설명하는 분산을 var_explained 변수에 저장(분산: 데이터의 다양성)\nvar_explained = pca.explained_variance_ratio_\n\n# 분산이 90% 이상인 주성분만을 선택하여 pcs 변수에 저장\npcs = pcs[:, var_explained > 0.9]\nreduced_df = pca.transform(df_copy)\n'

# %%
# reduced_df

# %%
 # 2번째 주성분을 사용하면 데이터의 차원이 두 개로 늘어나지만, 데이터의 성능은 향상되지 않고, 데이터의 성능이 떨어짐

# %% [markdown]
# # 차원축소해보기

# %%
# 2차원으로 만들기
# 데이터표준화
# 데이터의 크기를 동일하게 만드는 과정, 데이터차원 축소 & 데이터 특징을 비교 용이
scaler = StandardScaler()
df_copy = scaler.fit_transform(df_copy)


# 데이터의 공분산 행렬을 계산합니다.
# 공분산행렬 : 변수 간의 상관 관계 보여줌. 공분산행렬의 값이 크면 두 변수가 강하게 관련되어 있고, 공분산행렬의 값이 작으면 두 변수가 약하게 관련
cov = np.cov(df_copy.T)

# 공분산 행렬의 고유값과 고유벡터 계산
# 고유값:  행렬이 데이터의 변수 간의 상관 관계를 나타내는 척도
# 고유벡터: 행렬이 데이터의 변수 간의 관계를 나타내는 방향
eig_vals, eig_vecs = np.linalg.eig(cov)

# %%
# 분산이 큰 2개만 선택 (2차원 선택)
# 고유값의 크기가 큰 고유벡터를 선택
top_n = 2
eig_vecs = eig_vecs[:, :top_n]

new_df = df.dot(eig_vecs)

# 주성분의 설명력 계산
explained_variance = eig_vals[:top_n].sum() / cov.sum()

# 주성분의 설명력
print(f'주성분의 설명력: {explained_variance}')

# 0.65
# Out:
# 주성분의 설명력: 0.6521621627409175

# %%
# 3차원 선택

# 고유값의 크기가 큰 고유벡터를 선택
top_n = 3
eig_vecs = eig_vecs[:, :top_n]

new_df3d = df.dot(eig_vecs)

explained_variance_3d = eig_vals[:top_n].sum() / cov.sum()

# 주성분의 설명력
print(f'주성분의 설명력: {explained_variance_3d}')

# 0.67
# Out:
# 주성분의 설명력: 0.6755044304609894

# %%
# 4차원  선택

# 고유값의 크기가 큰 고유벡터를 선택
top_n = 4
eig_vecs = eig_vecs[:, :top_n]

new_df4d = df.dot(eig_vecs)

explained_variance_4d = eig_vals[:top_n].sum() / cov.sum()

# 주성분의 설명력
print(f'주성분의 설명력: {explained_variance_4d}')

#0.70
# Out:
# 주성분의 설명력: 0.7096674874627941

# %%
# 5차원  선택

# 고유값의 크기가 큰 고유벡터를 선택
top_n = 5
eig_vecs = eig_vecs[:, :top_n]

new_df5d = df.dot(eig_vecs)

explained_variance_5d = eig_vals[:top_n].sum() / cov.sum()

# 주성분의 설명력
print(f'주성분의 설명력: {explained_variance_5d}')

# 0.87
# Out:
# 주성분의 설명력: 0.8722520805421451

# %%
# 6차원  선택

# 고유값의 크기가 큰 고유벡터를 선택
top_n = 6
eig_vecs = eig_vecs[:, :top_n]

new_df6d = df.dot(eig_vecs)

explained_variance_6d = eig_vals[:top_n].sum() / cov.sum()

# 주성분의 설명력
print(f'주성분의 설명력: {explained_variance_6d}')

# 0.94
# Out:
# 주성분의 설명력: 0.9445638713016861

# %%
# 7차원  선택

# 고유값의 크기가 큰 고유벡터를 선택
top_n = 7
eig_vecs = eig_vecs[:, :top_n]

new_df7d = df.dot(eig_vecs)

explained_variance_7d = eig_vals[:top_n].sum() / cov.sum()

# 주성분의 설명력
print(f'주성분의 설명력: {explained_variance_7d}')

# 1.03 : 과대적합 상태
# Out:
# 주성분의 설명력: 1.0365596951382252

# %%
# 주성분은 원래 데이터의 특성을 재조합하여 만든 새로운 특성 : 컬럼이름 없어짐

# %% [markdown]
# # 학습 데이터 결정하기 : 확인 후 결정

# %%
df.head()
# 0.9997
# Out:
#      동   단지명    전용면적  계약년월  층  건축년도   금리  부동산소비심리    보증금
# 0  165  2059   79.97     0  4    26  1.5    117.6  44000
# 2  165  2059   79.97     0  3    26  1.5    117.6  42000
# 3  165   453  133.46     0  8    23  1.5    117.6  80000
# 4  165   453  104.43     0  6    23  1.5    117.6  52000
# 5  165   453  104.43     0  3    23  1.5    117.6  55000

# %% [markdown]
# # 선형회귀 모델링 전, 종속변수의 정규 분포화

# %%
df1 = df[['동', '단지명', '전용면적', '계약년월', '층', '건축년도', '금리','부동산소비심리','보증금']]
df1.columns = ['dong', 'apt_name', 'area', 'contract_month', 'floor', 'construction_year', 'interest', 'psychology','deposit']

# %%
df1
# Out:
#        dong apt_name    area  contract_month  floor  construction_year  \
# 0       165     2059   79.97               0      4                 26
# 2       165     2059   79.97               0      3                 26
# 3       165      453  133.46               0      8                 23
# 4       165      453  104.43               0      6                 23
# 5       165      453  104.43               0      3                 23
# ...     ...      ...     ...             ...    ...                ...
# 481997  241     3890   59.76              35     15                 36
# 481998  241     3890   84.03              35      6                 36
# 481999  241     3890   50.37              35     22                 36
# 482000  241     3890   59.76              35     15                 36
# 482001  241     3890   59.76              35     11                 36
#
#         interest  psychology  deposit
# 0           1.50       117.6    44000
# 2           1.50       117.6    42000
# 3           1.50       117.6    80000
# 4           1.50       117.6    52000
# 5           1.50       117.6    55000
# ...          ...         ...      ...
# 481997      1.75        93.9    28500
# 481998      1.75        93.9    34000
# 481999      1.75        93.9    27000
# 482000      1.75        93.9    29000
# 482001      1.75        93.9    29500
#
# [320979 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#df1['deposit'].hist() #정규분포화 되어있는지 확인
#plt.figure(figsize=(8,6))
plt.figure()
sns.histplot(x= "deposit",
             data=df1,
             bins=30,
             kde=True,
             line_kws={"linewidth":2})
# Out:
# <Axes: xlabel='deposit', ylabel='Count'>

# %%
plt.figure() #Figure인스턴스의 역할은 이미지 전체의 영역을 확보하는 것
sns.displot(df1['deposit'], bins=30)

plt.xlabel('Price(10000 won)')
plt.title('Distribution of Price')
plt.show()

# %%
from scipy.stats import skew, kurtosis

data_skewness = df1['deposit'].skew()
data_kurtosis = df1['deposit'].kurtosis()

print("왜도:", data_skewness)
print("첨도:", data_kurtosis)
# 왜도 값이 0에 가까울수록 데이터가 대칭적인 분포에 가깝다 (데이터의 비대칭성을 나타냄)
# 첨도 값이 0에 가까울수록 데이터가 정규 분포에 가깝다 (데이터의 뾰족한 정도)
# Out:
# 왜도: 0.7221748958366361
# 첨도: 0.4278800597961552

# %% [markdown]
# ## 로그 변환

# %%
df1['log_price'] = np.log1p(df1['deposit']) #로그 변환 후 보증근 따로 보관 
real_price = df1['deposit']

# %%
f, (ax1, ax2) = plt.subplots(1,2,figsize=(12,6))

ax1.hist(real_price, bins=30)
ax1.set_title('Price Distribution')
ax1.set_xlabel('Price')

ax2.hist(df1['log_price'], bins=30)
ax2.set_title('Log Price Distribution')
ax2.set_xlabel('Log Price')

plt.show() #로그 변환했을 때와 하기 전의 보증금 정규분포도 확인 => 왼쪽으로 더 치우침!!

# %% [markdown]
# ## 제곱근 변환

# %%
df1['sqrt_price'] = np.sqrt(df1['deposit']) #제곱근 변환 데이터 따로 저장

# %%
f, (ax1, ax2) = plt.subplots(1,2,figsize=(12,6))

ax1.hist(real_price, bins=30)
ax1.set_title('Price Distribution')
ax1.set_xlabel('Price')

ax2.hist(df1['sqrt_price'], bins=30)
ax2.set_title('Sqrt Price Distribution')
ax2.set_xlabel('sqrt_price')

plt.show() #제곱근 변환했을 때와 하기 전의 보증금 정규분포도 확인 -> 이전보다 훨씬 정규화를 이룸

# %%
df1.head()
# Out:
#   dong apt_name    area  contract_month  floor  construction_year  interest  \
# 0  165     2059   79.97               0      4                 26       1.5
# 2  165     2059   79.97               0      3                 26       1.5
# 3  165      453  133.46               0      8                 23       1.5
# 4  165      453  104.43               0      6                 23       1.5
# 5  165      453  104.43               0      3                 23       1.5
#
#    psychology  deposit  log_price  sqrt_price
# 0       117.6    44000  10.691968  209.761770
# 2       117.6    42000  10.645449  204.939015
# 3       117.6    80000  11.289794  282.842712
# 4       117.6    52000  10.859018  228.035085
# 5       117.6    55000  10.915107  234.520788

# %%
df1.drop('log_price', axis=1, inplace=True) #로그화를 진행했던 데이터 열 삭제

# %%
df1.head()
# Out:
#   dong apt_name    area  contract_month  floor  construction_year  interest  \
# 0  165     2059   79.97               0      4                 26       1.5
# 2  165     2059   79.97               0      3                 26       1.5
# 3  165      453  133.46               0      8                 23       1.5
# 4  165      453  104.43               0      6                 23       1.5
# 5  165      453  104.43               0      3                 23       1.5
#
#    psychology  deposit  sqrt_price
# 0       117.6    44000  209.761770
# 2       117.6    42000  204.939015
# 3       117.6    80000  282.842712
# 4       117.6    52000  228.035085
# 5       117.6    55000  234.520788

# %%
df1.drop('deposit', axis=1, inplace=True)
df1.head()
# Out:
#   dong apt_name    area  contract_month  floor  construction_year  interest  \
# 0  165     2059   79.97               0      4                 26       1.5
# 2  165     2059   79.97               0      3                 26       1.5
# 3  165      453  133.46               0      8                 23       1.5
# 4  165      453  104.43               0      6                 23       1.5
# 5  165      453  104.43               0      3                 23       1.5
#
#    psychology  sqrt_price
# 0       117.6  209.761770
# 2       117.6  204.939015
# 3       117.6  282.842712
# 4       117.6  228.035085
# 5       117.6  234.520788

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320979 entries, 0 to 482001
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   dong               320979 non-null  object
#  1   apt_name           320979 non-null  object
#  2   area               320979 non-null  float64
#  3   contract_month     320979 non-null  int64
#  4   floor              320979 non-null  int64
#  5   construction_year  320979 non-null  int64
#  6   interest           320979 non-null  float64
#  7   psychology         320979 non-null  float64
#  8   sqrt_price         320979 non-null  float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 24.5+ MB

# %%
# 동과 단지명이 숫자화 되어 있지 않아 int형으로 변환
df1['dong'] = df1['dong'].astype('int64')
df1['apt_name'] = df1['apt_name'].astype('int64')

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320979 entries, 0 to 482001
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   dong               320979 non-null  int64
#  1   apt_name           320979 non-null  int64
#  2   area               320979 non-null  float64
#  3   contract_month     320979 non-null  int64
#  4   floor              320979 non-null  int64
#  5   construction_year  320979 non-null  int64
#  6   interest           320979 non-null  float64
#  7   psychology         320979 non-null  float64
#  8   sqrt_price         320979 non-null  float64
# dtypes: float64(4), int64(5)
# memory usage: 24.5 MB

# %% [markdown]
# ## 전용면적 확인

# %%
#전용면적

plt.figure()
sns.displot(df1['area'], bins=30)
plt.xlabel('Area(Square meter)')
plt.title('Distribution of Area')
plt.show()

# %%
# 제곱근
df1['sqrt_area'] = np.sqrt(df1['area'])
real_area = df1['area']

f, (ax1, ax2) = plt.subplots(1,2,figsize=(12,6))

ax1.hist(real_area, bins=30)
ax1.set_title('Distribution of Area')
ax1.set_xlabel('Area')

ax2.hist(df1['sqrt_area'], bins=30)
ax2.set_title('Distribution of Sqrt Area')
ax2.set_xlabel('Area')

plt.show()

# %%
df1.head()
# Out:
#    dong  apt_name    area  contract_month  floor  construction_year  interest  \
# 0   165      2059   79.97               0      4                 26       1.5
# 2   165      2059   79.97               0      3                 26       1.5
# 3   165       453  133.46               0      8                 23       1.5
# 4   165       453  104.43               0      6                 23       1.5
# 5   165       453  104.43               0      3                 23       1.5
#
#    psychology  sqrt_price  sqrt_area
# 0       117.6  209.761770   8.942595
# 2       117.6  204.939015   8.942595
# 3       117.6  282.842712  11.552489
# 4       117.6  228.035085  10.219100
# 5       117.6  234.520788  10.219100

# %%
df1.drop('area', axis=1, inplace=True)

# %%
df1 = df1[['dong', 'apt_name', 'contract_month', 'floor', 'construction_year', 'interest', 'sqrt_area', 'sqrt_price']]
df1.head()
# Out:
#    dong  apt_name  contract_month  floor  construction_year  interest  \
# 0   165      2059               0      4                 26       1.5
# 2   165      2059               0      3                 26       1.5
# 3   165       453               0      8                 23       1.5
# 4   165       453               0      6                 23       1.5
# 5   165       453               0      3                 23       1.5
#
#    sqrt_area  sqrt_price
# 0   8.942595  209.761770
# 2   8.942595  204.939015
# 3  11.552489  282.842712
# 4  10.219100  228.035085
# 5  10.219100  234.520788

# %%
df1.info() #데이터 한번 더 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320979 entries, 0 to 482001
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   dong               320979 non-null  int64
#  1   apt_name           320979 non-null  int64
#  2   contract_month     320979 non-null  int64
#  3   floor              320979 non-null  int64
#  4   construction_year  320979 non-null  int64
#  5   interest           320979 non-null  float64
#  6   sqrt_area          320979 non-null  float64
#  7   sqrt_price         320979 non-null  float64
# dtypes: float64(3), int64(5)
# memory usage: 22.0 MB

# %% [markdown]
# # 데이터 정규화

# %%
from sklearn.preprocessing import MinMaxScaler

column_names = df1.columns

# MinMaxScaler를 사용한 데이터 민맥스 스케일링
scaler = MinMaxScaler()
df1 = scaler.fit_transform(df1)

# 스케일링된 데이터를 DataFrame으로 변환
df1 = pd.DataFrame(df11, columns=column_names)

# 스케일링된 데이터 출력
df1.head()
# Out:
#        dong  apt_name  contract_month     floor  construction_year  interest  \
# 0  0.498489  0.310464             0.0  0.058824           0.456140       0.5
# 1  0.498489  0.310464             0.0  0.044118           0.456140       0.5
# 2  0.498489  0.068305             0.0  0.117647           0.403509       0.5
# 3  0.498489  0.068305             0.0  0.088235           0.403509       0.5
# 4  0.498489  0.068305             0.0  0.044118           0.403509       0.5
#
#    sqrt_area  sqrt_price
# 0   0.393781    0.637707
# 1   0.393781    0.621296
# 2   0.572113    0.886394
# 3   0.481004    0.699889
# 4   0.481004    0.721959

# %% [markdown]
# # 데이터 나누기

# %%
from sklearn.model_selection import train_test_split

X=df1.loc[:, ['dong', 'apt_name', 'contract_month', 'floor', 'construction_year', 'interest', 'sqrt_area']]
y=df1.loc[:, 'sqrt_price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (256783, 7) (256783,)
# (64196, 7) (64196,)

# %% [markdown]
# # 다중선형회귀 적용

# %%
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(X_train, y_train)

y_predict = mlr.predict(X_test) #예측데이터 생성

# %%
plt.scatter(y_test, y_predict, alpha=0.4)

sns.regplot(x=y_test, y=y_predict) #검증데이터와 예측데이터의 산점도 확인

plt.xlabel("Actual Rent")
plt.ylabel("Predicted Rent")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# 평가 지표 계산
mse = mean_squared_error(y_test, y_predict)
r2 = r2_score(y_test, y_predict)

# 평가 지표 출력
print("평균 제곱 오차 (MSE):", mse)
print("결정 계수 (R-squared):", r2)
#결정 계수(Coefficient of Determination): 회귀 모델의 성능을 평가하기 위한 지표로 1에 가까울수록 좋은 것임.

# 예측 결과 시각화
plt.scatter(y_test, y_predict)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red')
plt.xlabel("Actual Rent")
plt.ylabel("Predicted Rent")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()
# Out:
# 평균 제곱 오차 (MSE): 0.005479525767714648
# 결정 계수 (R-squared): 0.7920877443458532

# %%
# 학습된 모델의 회귀 계수와 절편 출력
print("회귀 계수:", mlr.coef_) #회귀 계수: 각 독립 변수가 종속 변수에 미치는 영향력
print("절편:", mlr.intercept_) #절    편 : 독립 변수가 0일 때의 종속 변수의 예측값
# Out:
# 회귀 계수: [-1.32415148e-01 -2.98820628e-01  3.70750574e-02  9.28818152e-02
#   6.23653148e-02  2.59602339e-04  5.67508234e-01]
# 절편: 0.4732226681470468

# %%
print(mlr.score(X_train, y_train)) #훈련 세트에 대한 결정계수 출력
# Out:
# 0.7897434405047677

# %%
#예측한 값 y_predict을 실제 값 y_test와 비교 -> 곡선형 그래프를 통해 확인.
plt.figure(figsize=(10, 5))   
ax1 = sns.distplot(y_test, hist=False, label="Actual")   
ax2 = sns.distplot(y_predict, hist=False, label="Predict", ax=ax1)
plt.xlabel('deposit')
plt.ylabel('Density')
plt.legend()
plt.show()
plt.close()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_2036\422437642.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(y_test, hist=False, label="Actual")
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_2036\422437642.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax2 = sns.distplot(y_predict, hist=False, label="Predict", ax=ax1)

# %% [markdown]
# # 신경망 선형회귀

# %%
X1=df1.loc[:, ['dong', 'apt_name', 'contract_month', 'floor', 'construction_year', 'interest', 'sqrt_area']]
y1=df1.loc[:, 'sqrt_price']

X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (256783, 7)
# (256783,)

# %%
import tensorflow as tf

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(input_dim=X_train.shape[1],
                                   units=1,
                                   activation='linear'))

tf.model.compile(loss='mse',
                 optimizer=tf.keras.optimizers.SGD(learning_rate=0.001))

# %%
loss = tf.model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 8025/8025 [==============================] - 6s 654us/step - loss: 0.0647
# Epoch 2/100
# 8025/8025 [==============================] - 5s 652us/step - loss: 0.0122
# Epoch 3/100
# 8025/8025 [==============================] - 5s 654us/step - loss: 0.0100
# Epoch 4/100
# 8025/8025 [==============================] - 5s 657us/step - loss: 0.0089
# Epoch 5/100
# 8025/8025 [==============================] - 5s 663us/step - loss: 0.0082
# Epoch 6/100
# 8025/8025 [==============================] - 5s 658us/step - loss: 0.0077
# Epoch 7/100
# 8025/8025 [==============================] - 5s 662us/step - loss: 0.0073
# Epoch 8/100
# 8025/8025 [==============================] - 5s 650us/step - loss: 0.0070
# Epoch 9/100
# 8025/8025 [==============================] - 5s 654us/step - loss: 0.0067
# Epoch 10/100
# 8025/8025 [==============================] - 5s 656us/step - loss: 0.0065
# Epoch 11/100
# 8025/8025 [==============================] - 5s 667us/step - loss: 0.0063
# Epoch 12/100
# 8025/8025 [==============================] - 5s 669us/step - loss: 0.0062
# Epoch 13/100
# 8025/8025 [==============================] - 5s 664us/step - loss: 0.0061
# Epoch 14/100
# 8025/8025 [==============================] - 5s 674us/step - loss: 0.0060
# Epoch 15/100
# 8025/8025 [==============================] - 5s 663us/step - loss: 0.0059
# Epoch 16/100
# 8025/8025 [==============================] - 5s 665us/step - loss: 0.0059
# Epoch 17/100
# 8025/8025 [==============================] - 5s 666us/step - loss: 0.0058
# Epoch 18/100
# 8025/8025 [==============================] - 5s 659us/step - loss: 0.0058
# Epoch 19/100
# 8025/8025 [==============================] - 5s 658us/step - loss: 0.0057
# Epoch 20/100
# 8025/8025 [==============================] - 5s 669us/step - loss: 0.0057
# Epoch 21/100
# 8025/8025 [==============================] - 5s 657us/step - loss: 0.0057
# Epoch 22/100
# 8025/8025 [==============================] - 5s 659us/step - loss: 0.0056
# Epoch 23/100
# 8025/8025 [==============================] - 5s 663us/step - loss: 0.0056
# Epoch 24/100
# 8025/8025 [==============================] - 5s 660us/step - loss: 0.0056
# Epoch 25/100
# 8025/8025 [==============================] - 5s 660us/step - loss: 0.0056
# Epoch 26/100
# 8025/8025 [==============================] - 5s 667us/step - loss: 0.0056
# Epoch 27/100
# 8025/8025 [==============================] - 5s 658us/step - loss: 0.0056
# Epoch 28/100
# 8025/8025 [==============================] - 5s 657us/step - loss: 0.0056
# Epoch 29/100
# 8025/8025 [==============================] - 5s 653us/step - loss: 0.0056
# Epoch 30/100
# 8025/8025 [==============================] - 5s 653us/step - loss: 0.0056
# Epoch 31/100
# 8025/8025 [==============================] - 5s 665us/step - loss: 0.0056
# Epoch 32/100
# 8025/8025 [==============================] - 5s 680us/step - loss: 0.0055
# Epoch 33/100
# 8025/8025 [==============================] - 5s 670us/step - loss: 0.0055
# Epoch 34/100
# 8025/8025 [==============================] - 5s 680us/step - loss: 0.0055
# Epoch 35/100
# 8025/8025 [==============================] - 6s 702us/step - loss: 0.0055
# Epoch 36/100
# 8025/8025 [==============================] - 5s 663us/step - loss: 0.0055
# Epoch 37/100
# 8025/8025 [==============================] - 5s 657us/step - loss: 0.0055
# Epoch 38/100
# 8025/8025 [==============================] - 5s 670us/step - loss: 0.0055
# Epoch 39/100
# 8025/8025 [==============================] - 5s 653us/step - loss: 0.0055
# Epoch 40/100
# 8025/8025 [==============================] - 5s 654us/step - loss: 0.0055
# Epoch 41/100
# 8025/8025 [==============================] - 5s 661us/step - loss: 0.0055
# Epoch 42/100
# 8025/8025 [==============================] - 5s 665us/step - loss: 0.0055
# Epoch 43/100
# 8025/8025 [==============================] - 5s 663us/step - loss: 0.0055
# Epoch 44/100
# 8025/8025 [==============================] - 5s 664us/step - loss: 0.0055
# Epoch 45/100
# 8025/8025 [==============================] - 5s 676us/step - loss: 0.0055
# Epoch 46/100
# 8025/8025 [==============================] - 5s 681us/step - loss: 0.0055
# Epoch 47/100
# 8025/8025 [==============================] - 5s 649us/step - loss: 0.0055
# Epoch 48/100
# 8025/8025 [==============================] - 5s 649us/step - loss: 0.0055
# Epoch 49/100
# 8025/8025 [==============================] - 5s 660us/step - loss: 0.0055
# Epoch 50/100
# 8025/8025 [==============================] - 5s 660us/step - loss: 0.0055
# Epoch 51/100
# 8025/8025 [==============================] - 5s 659us/step - loss: 0.0055
# Epoch 52/100
# 8025/8025 [==============================] - 5s 667us/step - loss: 0.0055
# Epoch 53/100
# 8025/8025 [==============================] - 5s 660us/step - loss: 0.0055
# Epoch 54/100
# 8025/8025 [==============================] - 6s 692us/step - loss: 0.0055
# Epoch 55/100
# 8025/8025 [==============================] - 5s 657us/step - loss: 0.0055
# Epoch 56/100
# 8025/8025 [==============================] - 5s 664us/step - loss: 0.0055
# Epoch 57/100
# 8025/8025 [==============================] - 5s 657us/step - loss: 0.0055
# Epoch 58/100
# 8025/8025 [==============================] - 5s 656us/step - loss: 0.0055
# Epoch 59/100
# 8025/8025 [==============================] - 5s 655us/step - loss: 0.0055
# Epoch 60/100
# 8025/8025 [==============================] - 5s 676us/step - loss: 0.0055
# Epoch 61/100
# 8025/8025 [==============================] - 5s 665us/step - loss: 0.0055
# Epoch 62/100
# 8025/8025 [==============================] - 5s 667us/step - loss: 0.0055
# Epoch 63/100
# 8025/8025 [==============================] - 5s 661us/step - loss: 0.0055
# Epoch 64/100
# 8025/8025 [==============================] - 6s 686us/step - loss: 0.0055
# Epoch 65/100
# 8025/8025 [==============================] - 5s 665us/step - loss: 0.0055
# Epoch 66/100
# 8025/8025 [==============================] - 5s 666us/step - loss: 0.0055
# Epoch 67/100
# 8025/8025 [==============================] - 5s 662us/step - loss: 0.0055
# Epoch 68/100
# 8025/8025 [==============================] - 5s 669us/step - loss: 0.0055
# Epoch 69/100
# 8025/8025 [==============================] - 5s 661us/step - loss: 0.0055
# Epoch 70/100
# 8025/8025 [==============================] - 5s 665us/step - loss: 0.0055
# Epoch 71/100
# 8025/8025 [==============================] - 5s 668us/step - loss: 0.0055
# Epoch 72/100
# 8025/8025 [==============================] - 5s 663us/step - loss: 0.0055
# Epoch 73/100
# 8025/8025 [==============================] - 5s 656us/step - loss: 0.0055
# Epoch 74/100
# 8025/8025 [==============================] - 5s 665us/step - loss: 0.0055
# Epoch 75/100
# 8025/8025 [==============================] - 5s 675us/step - loss: 0.0055
# Epoch 76/100
# 8025/8025 [==============================] - 5s 680us/step - loss: 0.0055
# Epoch 77/100
# 8025/8025 [==============================] - 5s 670us/step - loss: 0.0055
# Epoch 78/100
# 8025/8025 [==============================] - 5s 670us/step - loss: 0.0055
# Epoch 79/100
# 8025/8025 [==============================] - 5s 666us/step - loss: 0.0055
# Epoch 80/100
# 8025/8025 [==============================] - 5s 669us/step - loss: 0.0055
# Epoch 81/100
# 8025/8025 [==============================] - 5s 662us/step - loss: 0.0055
# Epoch 82/100
# 8025/8025 [==============================] - 5s 675us/step - loss: 0.0055
# Epoch 83/100
# 8025/8025 [==============================] - 5s 673us/step - loss: 0.0055
# Epoch 84/100
# 8025/8025 [==============================] - 5s 665us/step - loss: 0.0055
# Epoch 85/100
# 8025/8025 [==============================] - 5s 659us/step - loss: 0.0055
# Epoch 86/100
# 8025/8025 [==============================] - 5s 658us/step - loss: 0.0055
# Epoch 87/100
# 8025/8025 [==============================] - 5s 663us/step - loss: 0.0055
# Epoch 88/100
# 8025/8025 [==============================] - 5s 666us/step - loss: 0.0055
# Epoch 89/100
# 8025/8025 [==============================] - 6s 687us/step - loss: 0.0055
# Epoch 90/100
# 8025/8025 [==============================] - 5s 675us/step - loss: 0.0055
# Epoch 91/100
# 8025/8025 [==============================] - 5s 653us/step - loss: 0.0055
# Epoch 92/100
# 8025/8025 [==============================] - 5s 653us/step - loss: 0.0055
# Epoch 93/100
# 8025/8025 [==============================] - 5s 660us/step - loss: 0.0055
# Epoch 94/100
# 8025/8025 [==============================] - 5s 670us/step - loss: 0.0055
# Epoch 95/100
# 8025/8025 [==============================] - 5s 659us/step - loss: 0.0055
# Epoch 96/100
# 8025/8025 [==============================] - 5s 661us/step - loss: 0.0055
# Epoch 97/100
# 8025/8025 [==============================] - 5s 655us/step - loss: 0.0055
# Epoch 98/100
# 8025/8025 [==============================] - 5s 649us/step - loss: 0.0055
# Epoch 99/100
# 8025/8025 [==============================] - 5s 654us/step - loss: 0.0055
# Epoch 100/100
# 8025/8025 [==============================] - 5s 657us/step - loss: 0.0055

# %%
predictions = tf.model.predict(X_test) #훈련시킨 선형회귀 모델로 새로운 값 넣어서 예측
score = tf.model.evaluate(X_test, y_test) #평가에 사용될 데이터와 실제값

print('Prediction: \n', predictions)
print('Cost : ', score)
# Out:
# 2007/2007 [==============================] - 1s 575us/step
# 2007/2007 [==============================] - 1s 677us/step - loss: 0.0055
# Prediction:
#  [[0.31579244]
#  [0.5893804 ]
#  [0.68845665]
#  ...
#  [0.7216805 ]
#  [0.6752707 ]
#  [0.42899305]]
# Cost :  0.00549095356836915

# %%
#신경망 선형회귀 예측한 값 predictions을 실제 값 y_data와 비교 
plt.figure(figsize=(10, 5))   
ax1 = sns.distplot(y_test, hist=False, label="Actual") #실제값  
ax2 = sns.distplot(predictions, hist=False, label="Predict", ax=ax1) #예측값
plt.xlabel('deposit')
plt.ylabel('Density')

plt.legend()
plt.show()
plt.close()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_2036\2963959832.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(y_test, hist=False, label="Actual") #실제값
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_2036\2963959832.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax2 = sns.distplot(predictions, hist=False, label="Predict", ax=ax1) #예측값
